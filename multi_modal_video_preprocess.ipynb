# %% [markdown]
# ### 수행순서
#
# #### 1. 얼굴 위치 정보, 나이, 감정정보가 있는 사물(얼굴)만 어노테이션으로 파싱
# #### 2. 파싱한 어노테이션을 읽어와서 224x224가 넘는 얼굴만 가져옴
#
# ### 필요 라이브러리 tqdm, ray
#
# ### 준비사항
# * 사전에 AiHub의 [멀티모달영상데이터](http://aihub.or.kr/aidata/137)를 다운로드하여 압축해제
# * 압축 해제한 폴더는 CLIP_FOLDER에 셋팅해줌
# * 현재는 zip파일 하나 당 처리하도록 구성되어 있음

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']=''
os.environ['BASE_FOLDER'] = os.getcwd()
BASE_FOLDER = os.getcwd()
print("BASE_FOLDER", BASE_FOLDER)

import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image
import dlib

import copy
import csv
import json
import pickle
import ipywidgets
from glob import glob
from tqdm import tqdm

import ray

# 병렬처리 라이브러리 호출
ray.shutdown()
# ray.init(num_cpus=8, num_gpus=0)
ray.init(webui_host='0.0.0.0')
#     memory=2000 * 1024 * 1024,
#     object_store_memory=200 * 1024 * 1024,
#     driver_object_store_memory=100 * 1024 * 1024)

# %% [markdown]
# ## 1. 얼굴 위치 정보, 나이, 감정정보가 있는 사물(얼굴을 포함 한)만 어노테이션으로 파싱

# %%
# 파싱 된 비디오 프레임들과 어노테이션 파일이 출력 될 폴더 
OUTPUT_FOLDER = './result'

# 압축 풀린 폴더 선택
CLIP_FOLDER = '0001-0400'
# CLIP_FOLDER = '0801-1200'

# 압축 풀린 폴더 및의 파일들
CLIP_FOLDER_PATHS = glob(os.path.join(CLIP_FOLDER, '*'))

# 비디오 파일과 어노테이션 파일 경로 로드
clip_json_paths = glob(os.path.join(CLIP_FOLDER, "*/*.json"))
clip_mp4_paths = glob(os.path.join(CLIP_FOLDER, "*/*.mp4"))
clip_json_paths.sort(), clip_mp4_paths.sort()
# Out:
# (None, None)

# %%
BASE_FOLDER, CLIP_FOLDER

# %% [markdown]
# ### 1.1 MP4파일들로 부터 비디오 프레임 생성 및 어노테이션 생성

# %%
def video_to_frames(clip_path:str):
    # "multi-modal-video"+"0001-0400/clip_324"
    
    output_paths = []
        
    # path setting
    # ['multi-modal-video', '0001-0400', 'clip_98']
    path = os.path.normpath(clip_path)
    split_paths = path.split(os.sep)
    
    # multi-modal-video/0001-0400/clip_98/clip_98.mp4
    video_path = os.path.join('/'+os.path.join(*split_paths), split_paths[-1]+'.mp4')

    # result/0001-0400/clip_98/frame_images
    output_folder_path = os.path.join(OUTPUT_FOLDER, *split_paths[-2:])
    
    # load video
    vidcap = cv2.VideoCapture(video_path)
    success, image = vidcap.read()

    # save video frames as jpg
    count = 1
    while success:
        os.makedirs(output_folder_path,exist_ok=True)
        output_path = os.path.join(output_folder_path,"%d.jpg" % count)
        output_paths.append(output_path)
        cv2.imwrite(output_path, image)     # save frame as JPEG file
        success, image = vidcap.read()
        #print('Read a new frame: ', success, output_path)
        count += 1
        
    return output_paths


def json_to_info(clip_full_path:str):
    """ 비디오 프레임들을 인물 정보와 매칭 시킨 어노테이션 생성
    inputs:
        clip_full_path: 비디오 클립 전체 폴더 경로
    outputs:
        results: dictionary, 매칭 된 어노테이션 정보
    
    """
    results = {}
    
    #make json path
    splited_path = os.path.split(clip_full_path)
    clip_json_path = os.path.join(clip_full_path, splited_path[-1]+'.json')    
    
    with open(clip_json_path, 'r') as f:
        o_json = json.load(f)
        
    #     # seq 대로 불러오기 위해 frame_idx를 사용
    #     data_len = len(o_json['data'])
    
    # 사람정보 읽어오기
    dict_actors = o_json['actor']
    
    for frame_idx in o_json['data']:
        #print('frame_id: ', frame_idx)
        data = o_json['data'][frame_idx]

        for obj_id in o_json['data'][frame_idx]:
            # o_json['data'][frame frame_idx][obj]
            
            #print('obj_id : ', obj_id)
            #print('o_json_frame_obj ' , o_json['data'][frame_idx][str(obj_id)])
            
            xtl = 0
            xbr = 0
            ytl = 0
            ybr = 0
            person_id = 0
            age = 0
            gender = ''
            emotion = ''
            try:
                person_id = copy.copy(o_json['data'][frame_idx][str(obj_id)]['person_id'])
                age       = copy.copy(dict_actors[person_id]['age'])
                gender    = copy.copy(dict_actors[person_id]['gender'])
                
                try:
                    img_emotion = o_json['data'][frame_idx][str(obj_id)]['emotion']['image']['emotion']
                    if img_emotion != "":
                        emotion   = copy.copy(o_json['data'][frame_idx][str(obj_id)]['emotion'])

                        xtl = int(round(float(o_json['data'][frame_idx][str(obj_id)]['xtl'])))
                        xbr = int(round(float(o_json['data'][frame_idx][str(obj_id)]['xbr'])))
                        ytl = int(round(float(o_json['data'][frame_idx][str(obj_id)]['ytl'])))
                        ybr = int(round(float(o_json['data'][frame_idx][str(obj_id)]['ybr'])))
                        #print(frame_idx, person_id, age, gender, emotion, xtl, xbr, ytl, ybr)
                        results[frame_idx] = {'person_id':person_id, 'age':age, 'gender':gender, 'emotion':emotion, 
                                          'xtl':xtl, 'xbr':xbr, 'ytl':ytl, 'ybr':ybr}                    
                    else:
                        continue
                except KeyError as e:
                    pass

            except KeyError as e:
                pass
    
    return results

@ray.remote
def parallel_write(clips:list):
    print(clips)
    
    for clip in clips:
        # ["0001-0400/clip_324",...]
    
        face_info = {}
        face_info_with_imgs = {}    

        print('clip_id: ', clip)
        face_info_with_imgs[clip] = {}

        # parsing video 
        # "multi-modal-video"+"0001-0400/clip_324"
        clip_full_path = os.path.join(BASE_FOLDER, clip)
        frame_paths = video_to_frames(clip_full_path)
        print('video_to_frames done!!')

        # parsing json
        person_infos = json_to_info(clip_full_path)
        print('json_to_info done!!')
        #     print(person_infos)

        total_frame_len = len(person_infos)
        for frame_idx in tqdm(person_infos.keys()):

            d_p_info = person_infos[str(frame_idx)]

            frame_image_path = os.path.join(OUTPUT_FOLDER, clip, str(frame_idx)+'.jpg')

            person_id = copy.copy(d_p_info['person_id'])
            age     = copy.copy(d_p_info['age'])
            gender  = copy.copy(d_p_info['gender'])
            emotion = copy.copy(d_p_info['emotion'])
            xtl = copy.copy(d_p_info['xtl'])
            xbr = copy.copy(d_p_info['xbr'])
            ytl = copy.copy(d_p_info['ytl'])
            ybr = copy.copy(d_p_info['ybr'])        

            face_info_with_imgs[clip][str(frame_idx)] = {'person_id':person_id, 'age':age, 'gender':gender, 'emotion':emotion, 
                              'xtl':xtl, 'xbr':xbr, 'ytl':ytl, 'ybr':ybr, 'frame_image_path':frame_image_path}


        mid_result_output_path = os.path.join(OUTPUT_FOLDER, clip+'.jsonpickle' )
        print(mid_result_output_path)

        with open(mid_result_output_path, 'wb') as f:
            pickle.dump(face_info_with_imgs, f)

# %%
# %%time

# clip
## frame
parallelism = 100
sub_tak_idxes = len(CLIP_FOLDER_PATHS) // parallelism
remainings = len(CLIP_FOLDER_PATHS) - (sub_tak_idxes * parallelism)

ray.get([parallel_write.remote(CLIP_FOLDER_PATHS[i*sub_tak_idxes:(i+1)*sub_tak_idxes]) for i in range(100)])
if remainings != 0:
    parallel_write(CLIP_FOLDER_PATHS[-remainings:])
# Out:
# (pid=69931) ['0001-0400/clip_333', '0001-0400/clip_334', '0001-0400/clip_335', '0001-0400/clip_336']
# (pid=69931) clip_id:  0001-0400/clip_333
# (pid=69942) ['0001-0400/clip_351', '0001-0400/clip_352', '0001-0400/clip_353', '0001-0400/clip_354']
# (pid=69942) clip_id:  0001-0400/clip_351
# (pid=69952) ['0001-0400/clip_315', '0001-0400/clip_316', '0001-0400/clip_317', '0001-0400/clip_318']
# (pid=69952) clip_id:  0001-0400/clip_315
# (pid=69958) ['0001-0400/clip_232', '0001-0400/clip_233', '0001-0400/clip_234', '0001-0400/clip_235']
# (pid=69958) clip_id:  0001-0400/clip_232
# (pid=69935) ['0001-0400/clip_283', '0001-0400/clip_284', '0001-0400/clip_285', '0001-0400/clip_286']
# (pid=69935) clip_id:  0001-0400/clip_283
# (pid=69959) ['0001-0400/clip_24', '0001-0400/clip_240', '0001-0400/clip_241', '0001-0400/clip_242']
# (pid=69959) clip_id:  0001-0400/clip_24
# (pid=69962) ['0001-0400/clip_33', '0001-0400/clip_330', '0001-0400/clip_331', '0001-0400/clip_332']
# (pid=69962) clip_id:  0001-0400/clip_33
# (pid=69997) ['0001-0400/clip_261', '0001-0400/clip_262', '0001-0400/clip_263', '0001-0400/clip_264']
# (pid=69997) clip_id:  0001-0400/clip_261
# (pid=69933) ['0001-0400/clip_243', '0001-0400/clip_244', '0001-0400/clip_245', '0001-0400/clip_246']
# (pid=69933) clip_id:  0001-0400/clip_243
# (pid=69943) ['0001-0400/clip_269', '0001-0400/clip_27', '0001-0400/clip_270', '0001-0400/clip_271']
# (pid=69943) clip_id:  0001-0400/clip_269
# (pid=69934) ['0001-0400/clip_218', '0001-0400/clip_219', '0001-0400/clip_22', '0001-0400/clip_220']
# (pid=69934) clip_id:  0001-0400/clip_218
# (pid=69956) ['0001-0400/clip_258', '0001-0400/clip_259', '0001-0400/clip_26', '0001-0400/clip_260']
# (pid=69956) clip_id:  0001-0400/clip_258
# (pid=69941) ['0001-0400/clip_229', '0001-0400/clip_23', '0001-0400/clip_230', '0001-0400/clip_231']
# (pid=69941) clip_id:  0001-0400/clip_229
# (pid=69939) ['0001-0400/clip_225', '0001-0400/clip_226', '0001-0400/clip_227', '0001-0400/clip_228']
# (pid=69939) clip_id:  0001-0400/clip_225
# (pid=69972) ['0001-0400/clip_214', '0001-0400/clip_215', '0001-0400/clip_216', '0001-0400/clip_217']
# (pid=69972) clip_id:  0001-0400/clip_214
# (pid=69932) ['0001-0400/clip_20', '0001-0400/clip_200', '0001-0400/clip_201', '0001-0400/clip_202']
# (pid=69932) clip_id:  0001-0400/clip_20
# (pid=69945) ['0001-0400/clip_250', '0001-0400/clip_251', '0001-0400/clip_252', '0001-0400/clip_253']
# (pid=69945) clip_id:  0001-0400/clip_250
# (pid=69938) ['0001-0400/clip_207', '0001-0400/clip_208', '0001-0400/clip_209', '0001-0400/clip_21']
# (pid=69938) clip_id:  0001-0400/clip_207
# (pid=69930) ['0001-0400/clip_197', '0001-0400/clip_198', '0001-0400/clip_199', '0001-0400/clip_2']
# (pid=69930) clip_id:  0001-0400/clip_197
# (pid=69973) ['0001-0400/clip_193', '0001-0400/clip_194', '0001-0400/clip_195', '0001-0400/clip_196']
# (pid=69973) clip_id:  0001-0400/clip_193
# (pid=69946) ['0001-0400/clip_28', '0001-0400/clip_280', '0001-0400/clip_281', '0001-0400/clip_282']
# (pid=69946) clip_id:  0001-0400/clip_28
# (pid=69961) ['0001-0400/clip_276', '0001-0400/clip_277', '0001-0400/clip_278', '0001-0400/clip_279']
# (pid=69961) clip_id:  0001-0400/clip_276
# (pid=69960) ['0001-0400/clip_287', '0001-0400/clip_288', '0001-0400/clip_289', '0001-0400/clip_29']
# (pid=69960) clip_id:  0001-0400/clip_287
# (pid=69985) ['0001-0400/clip_298', '0001-0400/clip_299', '0001-0400/clip_3', '0001-0400/clip_30']
# (pid=69985) clip_id:  0001-0400/clip_298
# (pid=69950) ['0001-0400/clip_304', '0001-0400/clip_305', '0001-0400/clip_306', '0001-0400/clip_307']
# (pid=69950) clip_id:  0001-0400/clip_304
# (pid=69998) ['0001-0400/clip_254', '0001-0400/clip_255', '0001-0400/clip_256', '0001-0400/clip_257']
# (pid=69998) clip_id:  0001-0400/clip_254
# (pid=69991) ['0001-0400/clip_294', '0001-0400/clip_295', '0001-0400/clip_296', '0001-0400/clip_297']
# (pid=69991) clip_id:  0001-0400/clip_294
# (pid=69969) ['0001-0400/clip_308', '0001-0400/clip_309', '0001-0400/clip_31', '0001-0400/clip_310']
# (pid=69969) clip_id:  0001-0400/clip_308
# (pid=69976) ['0001-0400/clip_311', '0001-0400/clip_312', '0001-0400/clip_313', '0001-0400/clip_314']
# (pid=69976) clip_id:  0001-0400/clip_311
# (pid=69979) ['0001-0400/clip_37', '0001-0400/clip_370', '0001-0400/clip_371', '0001-0400/clip_372']
# (pid=69979) clip_id:  0001-0400/clip_37
# (pid=69944) ['0001-0400/clip_210', '0001-0400/clip_211', '0001-0400/clip_212', '0001-0400/clip_213']
# (pid=69944) clip_id:  0001-0400/clip_210
# (pid=70010) ['0001-0400/clip_247', '0001-0400/clip_248', '0001-0400/clip_249', '0001-0400/clip_25']
# (pid=70010) clip_id:  0001-0400/clip_247
# (pid=70003) ['0001-0400/clip_319', '0001-0400/clip_32', '0001-0400/clip_320', '0001-0400/clip_321']
# (pid=70003) clip_id:  0001-0400/clip_319
# (pid=69983) ['0001-0400/clip_326', '0001-0400/clip_327', '0001-0400/clip_328', '0001-0400/clip_329']
# (pid=69983) clip_id:  0001-0400/clip_326
# (pid=69977) ['0001-0400/clip_337', '0001-0400/clip_338', '0001-0400/clip_339', '0001-0400/clip_34']
# (pid=69977) clip_id:  0001-0400/clip_337
# (pid=69954) ['0001-0400/clip_344', '0001-0400/clip_345', '0001-0400/clip_346', '0001-0400/clip_347']
# (pid=69954) clip_id:  0001-0400/clip_344
# (pid=69987) ['0001-0400/clip_164', '0001-0400/clip_165', '0001-0400/clip_166', '0001-0400/clip_167']
# (pid=69987) clip_id:  0001-0400/clip_164
# (pid=70014) ['0001-0400/clip_135', '0001-0400/clip_136', '0001-0400/clip_137', '0001-0400/clip_138']
# (pid=70014) clip_id:  0001-0400/clip_135
# (pid=69982) ['0001-0400/clip_355', '0001-0400/clip_356', '0001-0400/clip_357', '0001-0400/clip_358']
# (pid=69982) clip_id:  0001-0400/clip_355
# (pid=69940) ['0001-0400/clip_366', '0001-0400/clip_367', '0001-0400/clip_368', '0001-0400/clip_369']
# (pid=69940) clip_id:  0001-0400/clip_366
# (pid=69989) ['0001-0400/clip_120', '0001-0400/clip_121', '0001-0400/clip_122', '0001-0400/clip_123']
# (pid=69989) clip_id:  0001-0400/clip_120
# (pid=69995) ['0001-0400/clip_380', '0001-0400/clip_381', '0001-0400/clip_382', '0001-0400/clip_383']
# (pid=69995) clip_id:  0001-0400/clip_380
# (pid=69951) ['0001-0400/clip_359', '0001-0400/clip_36', '0001-0400/clip_360', '0001-0400/clip_361']
# (pid=69951) clip_id:  0001-0400/clip_359
# (pid=69978) ['0001-0400/clip_265', '0001-0400/clip_266', '0001-0400/clip_267', '0001-0400/clip_268']
# (pid=69978) clip_id:  0001-0400/clip_265
# (pid=69988) ['0001-0400/clip_179', '0001-0400/clip_18', '0001-0400/clip_180', '0001-0400/clip_181']
# (pid=69988) clip_id:  0001-0400/clip_179
# (pid=69968) ['0001-0400/clip_1', '0001-0400/clip_10', '0001-0400/clip_100', '0001-0400/clip_101']
# (pid=69968) clip_id:  0001-0400/clip_1
# (pid=69990) ['0001-0400/clip_160', '0001-0400/clip_161', '0001-0400/clip_162', '0001-0400/clip_163']
# (pid=69990) clip_id:  0001-0400/clip_160
# (pid=70013) ['0001-0400/clip_128', '0001-0400/clip_129', '0001-0400/clip_13', '0001-0400/clip_130']
# (pid=70013) clip_id:  0001-0400/clip_128
# (pid=69974) ['0001-0400/clip_113', '0001-0400/clip_114', '0001-0400/clip_115', '0001-0400/clip_116']
# (pid=69974) clip_id:  0001-0400/clip_113
# (pid=70006) ['0001-0400/clip_153', '0001-0400/clip_154', '0001-0400/clip_155', '0001-0400/clip_156']
# (pid=70006) clip_id:  0001-0400/clip_153
# (pid=70001) ['0001-0400/clip_102', '0001-0400/clip_103', '0001-0400/clip_104', '0001-0400/clip_105']
# (pid=70001) clip_id:  0001-0400/clip_102
# (pid=69975) ['0001-0400/clip_221', '0001-0400/clip_222', '0001-0400/clip_223', '0001-0400/clip_224']
# (pid=69975) clip_id:  0001-0400/clip_221
# (pid=70012) ['0001-0400/clip_19', '0001-0400/clip_190', '0001-0400/clip_191', '0001-0400/clip_192']
# (pid=70012) clip_id:  0001-0400/clip_19
# (pid=69971) ['0001-0400/clip_15', '0001-0400/clip_150', '0001-0400/clip_151', '0001-0400/clip_152']
# (pid=69971) clip_id:  0001-0400/clip_15
# (pid=69970) ['0001-0400/clip_377', '0001-0400/clip_378', '0001-0400/clip_379', '0001-0400/clip_38']
# (pid=69970) clip_id:  0001-0400/clip_377
# (pid=70008) ['0001-0400/clip_300', '0001-0400/clip_301', '0001-0400/clip_302', '0001-0400/clip_303']
# (pid=70008) clip_id:  0001-0400/clip_300
# (pid=70009) ['0001-0400/clip_373', '0001-0400/clip_374', '0001-0400/clip_375', '0001-0400/clip_376']
# (pid=70009) clip_id:  0001-0400/clip_373
# (pid=69999) ['0001-0400/clip_322', '0001-0400/clip_323', '0001-0400/clip_324', '0001-0400/clip_325']
# (pid=69999) clip_id:  0001-0400/clip_322
# (pid=69981) ['0001-0400/clip_168', '0001-0400/clip_169', '0001-0400/clip_17', '0001-0400/clip_170']
# (pid=69981) clip_id:  0001-0400/clip_168
# (pid=69992) ['0001-0400/clip_348', '0001-0400/clip_349', '0001-0400/clip_35', '0001-0400/clip_350']
# (pid=69992) clip_id:  0001-0400/clip_348
# (pid=69936) ['0001-0400/clip_146', '0001-0400/clip_147', '0001-0400/clip_148', '0001-0400/clip_149']
# (pid=69936) clip_id:  0001-0400/clip_146
# (pid=69937) ['0001-0400/clip_182', '0001-0400/clip_183', '0001-0400/clip_184', '0001-0400/clip_185']
# (pid=69937) clip_id:  0001-0400/clip_182
# (pid=69996) ['0001-0400/clip_106', '0001-0400/clip_107', '0001-0400/clip_108', '0001-0400/clip_109']
# (pid=69996) clip_id:  0001-0400/clip_106
# (pid=70007) ['0001-0400/clip_175', '0001-0400/clip_176', '0001-0400/clip_177', '0001-0400/clip_178']
# (pid=70007) clip_id:  0001-0400/clip_175
# (pid=70005) ['0001-0400/clip_139', '0001-0400/clip_14', '0001-0400/clip_140', '0001-0400/clip_141']
# (pid=70005) clip_id:  0001-0400/clip_139
# (pid=69986) ['0001-0400/clip_203', '0001-0400/clip_204', '0001-0400/clip_205', '0001-0400/clip_206']
# (pid=69986) clip_id:  0001-0400/clip_203
# (pid=69965) ['0001-0400/clip_186', '0001-0400/clip_187', '0001-0400/clip_188', '0001-0400/clip_189']
# (pid=69965) clip_id:  0001-0400/clip_186
# (pid=69984) ['0001-0400/clip_131', '0001-0400/clip_132', '0001-0400/clip_133', '0001-0400/clip_134']
# (pid=69984) clip_id:  0001-0400/clip_131
# (pid=69949) ['0001-0400/clip_362', '0001-0400/clip_363', '0001-0400/clip_364', '0001-0400/clip_365']
# (pid=69949) clip_id:  0001-0400/clip_362
# (pid=69948) ['0001-0400/clip_171', '0001-0400/clip_172', '0001-0400/clip_173', '0001-0400/clip_174']
# (pid=69948) clip_id:  0001-0400/clip_171
# (pid=69980) ['0001-0400/clip_117', '0001-0400/clip_118', '0001-0400/clip_119', '0001-0400/clip_12']
# (pid=69980) clip_id:  0001-0400/clip_117
# (pid=69994) ['0001-0400/clip_157', '0001-0400/clip_158', '0001-0400/clip_159', '0001-0400/clip_16']
# (pid=69994) clip_id:  0001-0400/clip_157
# (pid=70002) ['0001-0400/clip_384', '0001-0400/clip_385', '0001-0400/clip_386', '0001-0400/clip_387']
# (pid=70002) clip_id:  0001-0400/clip_384
# (pid=70011) ['0001-0400/clip_236', '0001-0400/clip_237', '0001-0400/clip_238', '0001-0400/clip_239']
# (pid=70011) clip_id:  0001-0400/clip_236
# (pid=69955) ['0001-0400/clip_11', '0001-0400/clip_110', '0001-0400/clip_111', '0001-0400/clip_112']
# (pid=69955) clip_id:  0001-0400/clip_11
# (pid=70004) ['0001-0400/clip_142', '0001-0400/clip_143', '0001-0400/clip_144', '0001-0400/clip_145']
# (pid=70004) clip_id:  0001-0400/clip_142
# (pid=69947) ['0001-0400/clip_290', '0001-0400/clip_291', '0001-0400/clip_292', '0001-0400/clip_293']
# (pid=69947) clip_id:  0001-0400/clip_290
# (pid=69993) ['0001-0400/clip_124', '0001-0400/clip_125', '0001-0400/clip_126', '0001-0400/clip_127']
# (pid=69993) clip_id:  0001-0400/clip_124
# (pid=69957) ['0001-0400/clip_340', '0001-0400/clip_341', '0001-0400/clip_342', '0001-0400/clip_343']
# (pid=69957) clip_id:  0001-0400/clip_340
# (pid=70000) ['0001-0400/clip_272', '0001-0400/clip_273', '0001-0400/clip_274', '0001-0400/clip_275']
# (pid=70000) clip_id:  0001-0400/clip_272
# (pid=70004) video_to_frames done!!
# (pid=70004) json_to_info done!!
# (pid=70004) ./result/0001-0400/clip_142.jsonpickle
# 100%|██████████| 941/941 [00:00<00:00, 28884.53it/s]
# (pid=70004) clip_id:  0001-0400/clip_143
# (pid=69968) video_to_frames done!!
# (pid=69968) json_to_info done!!
#   0%|          | 0/905 [00:00<?, ?it/s]
# (pid=69968) ./result/0001-0400/clip_1.jsonpickle
# (pid=69968) clip_id:  0001-0400/clip_10
# 100%|██████████| 905/905 [00:00<00:00, 27592.10it/s]
# (pid=69955) video_to_frames done!!
# (pid=69955) json_to_info done!!
#   0%|          | 0/882 [00:00<?, ?it/s]
# (pid=69955) ./result/0001-0400/clip_11.jsonpickle
# (pid=69955) clip_id:  0001-0400/clip_110
# 100%|██████████| 882/882 [00:00<00:00, 29871.02it/s]
# (pid=69930) video_to_frames done!!
# (pid=69930) json_to_info done!!
#   0%|          | 0/1082 [00:00<?, ?it/s]
# (pid=69930) ./result/0001-0400/clip_197.jsonpickle
# (pid=69930) clip_id:  0001-0400/clip_198
# 100%|██████████| 1082/1082 [00:00<00:00, 31229.91it/s]
# (pid=70006) video_to_frames done!!
# (pid=70006) json_to_info done!!
#   0%|          | 0/967 [00:00<?, ?it/s]
# (pid=70006) ./result/0001-0400/clip_153.jsonpickle
# (pid=70006) clip_id:  0001-0400/clip_154
# 100%|██████████| 967/967 [00:00<00:00, 41920.93it/s]
# (pid=69936) video_to_frames done!!
# (pid=69936) json_to_info done!!
# (pid=69936) ./result/0001-0400/clip_146.jsonpickle
# (pid=69936) clip_id:  0001-0400/clip_147
# 100%|██████████| 1118/1118 [00:00<00:00, 53995.42it/s]
# (pid=69946) video_to_frames done!!
# (pid=69946) json_to_info done!!
#   0%|          | 0/1142 [00:00<?, ?it/s]
# (pid=69946) ./result/0001-0400/clip_28.jsonpickle
# (pid=69946) clip_id:  0001-0400/clip_280
# 100%|██████████| 1142/1142 [00:00<00:00, 50622.97it/s]
# (pid=69990) video_to_frames done!!
# (pid=69990) json_to_info done!!
#   0%|          | 0/901 [00:00<?, ?it/s]
# (pid=69990) ./result/0001-0400/clip_160.jsonpickle
# 100%|██████████| 901/901 [00:00<00:00, 26644.11it/s]
# (pid=69990) clip_id:  0001-0400/clip_161
# (pid=69954) video_to_frames done!!
# (pid=69954) json_to_info done!!
# (pid=69980) video_to_frames done!!
# (pid=69954) ./result/0001-0400/clip_344.jsonpickle
# (pid=69954) clip_id:  0001-0400/clip_345
# 100%|██████████| 1089/1089 [00:00<00:00, 44963.74it/s]
# (pid=69980) json_to_info done!!
# (pid=69980) ./result/0001-0400/clip_117.jsonpickle
# (pid=69980) clip_id:  0001-0400/clip_118
# 100%|██████████| 1166/1166 [00:00<00:00, 45521.52it/s]
# (pid=69940) video_to_frames done!!
# (pid=69940) json_to_info done!!
# (pid=69940) ./result/0001-0400/clip_366.jsonpickle
# (pid=69940) clip_id:  0001-0400/clip_367
# 100%|██████████| 1153/1153 [00:00<00:00, 48768.52it/s]
# (pid=69932) video_to_frames done!!
# (pid=69932) json_to_info done!!
#   0%|          | 0/1278 [00:00<?, ?it/s]
# (pid=69932) ./result/0001-0400/clip_20.jsonpickle
# (pid=69932) clip_id:  0001-0400/clip_200
# 100%|██████████| 1278/1278 [00:00<00:00, 32966.91it/s]
# (pid=69975) video_to_frames done!!
# (pid=69962) video_to_frames done!!
# (pid=69975) json_to_info done!!
#   0%|          | 0/1279 [00:00<?, ?it/s]
# (pid=69975) ./result/0001-0400/clip_221.jsonpickle
# (pid=69975) clip_id:  0001-0400/clip_222
# 100%|██████████| 1279/1279 [00:00<00:00, 46938.16it/s]
# (pid=69962) json_to_info done!!
#   0%|          | 0/1312 [00:00<?, ?it/s]
# (pid=69962) ./result/0001-0400/clip_33.jsonpickle
# 100%|██████████| 1312/1312 [00:00<00:00, 49786.28it/s]
# (pid=69962) clip_id:  0001-0400/clip_330
# (pid=70007) video_to_frames done!!
# (pid=70007) json_to_info done!!
#   0%|          | 0/1177 [00:00<?, ?it/s]
# (pid=70007) ./result/0001-0400/clip_175.jsonpickle
# (pid=70007) clip_id:  0001-0400/clip_176
# 100%|██████████| 1177/1177 [00:00<00:00, 24056.10it/s]
# (pid=69994) video_to_frames done!!
# (pid=69994) json_to_info done!!
#   0%|          | 0/1251 [00:00<?, ?it/s]
# (pid=69994) ./result/0001-0400/clip_157.jsonpickle
# (pid=69994) clip_id:  0001-0400/clip_158
# 100%|██████████| 1251/1251 [00:00<00:00, 45900.54it/s]
# (pid=69996) video_to_frames done!!
# (pid=69996) json_to_info done!!
#   0%|          | 0/1126 [00:00<?, ?it/s]
# (pid=69996) ./result/0001-0400/clip_106.jsonpickle
# (pid=69996) clip_id:  0001-0400/clip_107
# 100%|██████████| 1126/1126 [00:00<00:00, 28728.63it/s]
# (pid=70009) video_to_frames done!!
# (pid=70009) json_to_info done!!
#   0%|          | 0/1191 [00:00<?, ?it/s]
# (pid=69971) video_to_frames done!!
# (pid=70009) ./result/0001-0400/clip_373.jsonpickle
# (pid=70009) clip_id:  0001-0400/clip_374
# 100%|██████████| 1191/1191 [00:00<00:00, 24520.39it/s]
# (pid=69971) json_to_info done!!
#   0%|          | 0/1254 [00:00<?, ?it/s]
# (pid=69971) ./result/0001-0400/clip_15.jsonpickle
# 100%|██████████| 1254/1254 [00:00<00:00, 45999.75it/s]
# (pid=69971) clip_id:  0001-0400/clip_150
# (pid=69934) video_to_frames done!!
# (pid=69934) json_to_info done!!
# (pid=69934) ./result/0001-0400/clip_218.jsonpickle
# 100%|██████████| 1396/1396 [00:00<00:00, 46073.84it/s]
# (pid=69934) clip_id:  0001-0400/clip_219
# (pid=69959) video_to_frames done!!
# (pid=69959) json_to_info done!!
#   0%|          | 0/1361 [00:00<?, ?it/s]
# (pid=69959) ./result/0001-0400/clip_24.jsonpickle
# (pid=69959) clip_id:  0001-0400/clip_240
# 100%|██████████| 1361/1361 [00:00<00:00, 20768.34it/s]
# (pid=69965) video_to_frames done!!
# (pid=69965) json_to_info done!!
#   0%|          | 0/1428 [00:00<?, ?it/s]
# (pid=69965) ./result/0001-0400/clip_186.jsonpickle
# (pid=69965) clip_id:  0001-0400/clip_187
# 100%|██████████| 1428/1428 [00:00<00:00, 35441.26it/s]
# (pid=69988) video_to_frames done!!
# (pid=69988) json_to_info done!!
#   0%|          | 0/1137 [00:00<?, ?it/s]
# (pid=69988) ./result/0001-0400/clip_179.jsonpickle
# (pid=69988) clip_id:  0001-0400/clip_18
# 100%|██████████| 1137/1137 [00:00<00:00, 44520.28it/s]
# (pid=69998) video_to_frames done!!
# (pid=69998) json_to_info done!!
# (pid=69998) ./result/0001-0400/clip_254.jsonpickle
# (pid=69998) clip_id:  0001-0400/clip_255
# 100%|██████████| 1190/1190 [00:00<00:00, 32707.88it/s]
# (pid=69974) video_to_frames done!!
# (pid=69974) json_to_info done!!
# (pid=69974) ./result/0001-0400/clip_113.jsonpickle
# (pid=69974) clip_id:  0001-0400/clip_114
# 100%|██████████| 1284/1284 [00:00<00:00, 39629.18it/s]
# (pid=69948) video_to_frames done!!
# (pid=69948) json_to_info done!!
# (pid=69948) ./result/0001-0400/clip_171.jsonpickle
# 100%|██████████| 1449/1449 [00:00<00:00, 41054.52it/s]
# (pid=69948) clip_id:  0001-0400/clip_172
# (pid=69973) video_to_frames done!!
# (pid=69973) json_to_info done!!
#   0%|          | 0/1259 [00:00<?, ?it/s]
# (pid=69973) ./result/0001-0400/clip_193.jsonpickle
# (pid=69973) clip_id:  0001-0400/clip_194
# 100%|██████████| 1259/1259 [00:00<00:00, 28312.69it/s]
# (pid=70005) video_to_frames done!!
# (pid=69938) video_to_frames done!!
# (pid=70005) json_to_info done!!
#   0%|          | 0/1410 [00:00<?, ?it/s]
# (pid=70005) ./result/0001-0400/clip_139.jsonpickle
# (pid=70005) clip_id:  0001-0400/clip_14
# 100%|██████████| 1410/1410 [00:00<00:00, 35801.88it/s]
# (pid=69938) json_to_info done!!
#   0%|          | 0/1390 [00:00<?, ?it/s]
# (pid=69938) ./result/0001-0400/clip_207.jsonpickle
# (pid=69938) clip_id:  0001-0400/clip_208
# 100%|██████████| 1390/1390 [00:00<00:00, 50568.41it/s]
# (pid=69933) video_to_frames done!!
# (pid=69933) json_to_info done!!
#   0%|          | 0/1294 [00:00<?, ?it/s]
# (pid=69933) ./result/0001-0400/clip_243.jsonpickle
# 100%|██████████| 1294/1294 [00:00<00:00, 45634.73it/s]
# (pid=69933) clip_id:  0001-0400/clip_244
# (pid=69935) video_to_frames done!!
# (pid=69935) json_to_info done!!
#   0%|          | 0/1295 [00:00<?, ?it/s]
# (pid=69935) ./result/0001-0400/clip_283.jsonpickle
# 100%|██████████| 1295/1295 [00:00<00:00, 25194.70it/s]
# (pid=69935) clip_id:  0001-0400/clip_284
# (pid=69970) video_to_frames done!!
# (pid=69970) json_to_info done!!
#   0%|          | 0/1401 [00:00<?, ?it/s]
# (pid=69970) ./result/0001-0400/clip_377.jsonpickle
# (pid=69970) clip_id:  0001-0400/clip_378
# 100%|██████████| 1401/1401 [00:00<00:00, 24754.90it/s]
# (pid=69991) video_to_frames done!!
# (pid=69991) json_to_info done!!
#   0%|          | 0/1331 [00:00<?, ?it/s]
# (pid=69991) ./result/0001-0400/clip_294.jsonpickle
# 100%|██████████| 1331/1331 [00:00<00:00, 27417.93it/s]
# (pid=69991) clip_id:  0001-0400/clip_295
# (pid=70012) video_to_frames done!!
# (pid=70012) json_to_info done!!
#   0%|          | 0/1591 [00:00<?, ?it/s]
# (pid=70012) ./result/0001-0400/clip_19.jsonpickle
# (pid=70012) clip_id:  0001-0400/clip_190
# 100%|██████████| 1591/1591 [00:00<00:00, 36546.51it/s]
# (pid=69945) video_to_frames done!!
# (pid=69987) video_to_frames done!!
# (pid=69987) json_to_info done!!
#   0%|          | 0/1456 [00:00<?, ?it/s]
# (pid=69945) json_to_info done!!
#   0%|          | 0/1510 [00:00<?, ?it/s]
# (pid=69987) ./result/0001-0400/clip_164.jsonpickle
# (pid=69987) clip_id:  0001-0400/clip_165
# 100%|██████████| 1456/1456 [00:00<00:00, 30777.21it/s]
# (pid=69945) ./result/0001-0400/clip_250.jsonpickle
# 100%|██████████| 1510/1510 [00:00<00:00, 26755.83it/s]
# (pid=69945) clip_id:  0001-0400/clip_251
# (pid=69997) video_to_frames done!!
# (pid=69997) json_to_info done!!
#   0%|          | 0/1377 [00:00<?, ?it/s]
# (pid=69997) ./result/0001-0400/clip_261.jsonpickle
# (pid=69997) clip_id:  0001-0400/clip_262
# 100%|██████████| 1377/1377 [00:00<00:00, 36127.26it/s]
# (pid=69950) video_to_frames done!!
# (pid=69950) json_to_info done!!
#   0%|          | 0/1624 [00:00<?, ?it/s]
# (pid=69950) ./result/0001-0400/clip_304.jsonpickle
# 100%|██████████| 1624/1624 [00:00<00:00, 32644.41it/s]
# (pid=69950) clip_id:  0001-0400/clip_305
# (pid=69944) video_to_frames done!!
# (pid=69944) json_to_info done!!
# (pid=69944) ./result/0001-0400/clip_210.jsonpickle
# 100%|██████████| 1546/1546 [00:00<00:00, 32211.15it/s]
# (pid=69944) clip_id:  0001-0400/clip_211
# (pid=69960) video_to_frames done!!
# (pid=69960) json_to_info done!!
#   0%|          | 0/1625 [00:00<?, ?it/s]
# (pid=69960) ./result/0001-0400/clip_287.jsonpickle
# (pid=69960) clip_id:  0001-0400/clip_288
# 100%|██████████| 1625/1625 [00:00<00:00, 28464.04it/s]
# (pid=69979) video_to_frames done!!
# (pid=69979) json_to_info done!!
#   0%|          | 0/1726 [00:00<?, ?it/s]
# (pid=69979) ./result/0001-0400/clip_37.jsonpickle
# (pid=69979) clip_id:  0001-0400/clip_370
# 100%|██████████| 1726/1726 [00:00<00:00, 22721.30it/s]
# (pid=69972) video_to_frames done!!
# (pid=69969) video_to_frames done!!
# (pid=69969) json_to_info done!!
# (pid=69972) json_to_info done!!
#   0%|          | 0/1756 [00:00<?, ?it/s]
# (pid=69969) ./result/0001-0400/clip_308.jsonpickle
# 100%|██████████| 1709/1709 [00:00<00:00, 48284.76it/s]
# (pid=69972) ./result/0001-0400/clip_214.jsonpickle
# (pid=69972) clip_id:  0001-0400/clip_215
# 100%|██████████| 1756/1756 [00:00<00:00, 48193.67it/s]
# (pid=69969) clip_id:  0001-0400/clip_309
# (pid=69986) video_to_frames done!!
# (pid=69986) json_to_info done!!
#   0%|          | 0/1733 [00:00<?, ?it/s]
# (pid=69986) ./result/0001-0400/clip_203.jsonpickle
# (pid=69986) clip_id:  0001-0400/clip_204
# 100%|██████████| 1733/1733 [00:00<00:00, 29720.44it/s]
# (pid=69941) video_to_frames done!!
# (pid=70002) video_to_frames done!!
# (pid=69941) json_to_info done!!
#   0%|          | 0/1583 [00:00<?, ?it/s]
# (pid=69949) video_to_frames done!!
# (pid=69941) ./result/0001-0400/clip_229.jsonpickle
# (pid=69941) clip_id:  0001-0400/clip_23
# 100%|██████████| 1583/1583 [00:00<00:00, 32094.82it/s]
# (pid=70002) json_to_info done!!
#   0%|          | 0/1631 [00:00<?, ?it/s]
# (pid=69949) json_to_info done!!
#   0%|          | 0/1584 [00:00<?, ?it/s]
# (pid=70002) ./result/0001-0400/clip_384.jsonpickle
# (pid=70002) clip_id:  0001-0400/clip_385
# 100%|██████████| 1631/1631 [00:00<00:00, 50226.21it/s]
# (pid=69949) ./result/0001-0400/clip_362.jsonpickle
# 100%|██████████| 1584/1584 [00:00<00:00, 38060.79it/s]
# (pid=69949) clip_id:  0001-0400/clip_363
# (pid=69958) video_to_frames done!!
# (pid=69958) json_to_info done!!
# (pid=69958) ./result/0001-0400/clip_232.jsonpickle
# 100%|██████████| 1618/1618 [00:00<00:00, 32664.22it/s]
# (pid=69958) clip_id:  0001-0400/clip_233
# (pid=69978) video_to_frames done!!
# (pid=69978) json_to_info done!!
# (pid=69978) ./result/0001-0400/clip_265.jsonpickle
# 100%|██████████| 1660/1660 [00:00<00:00, 39727.63it/s]
# (pid=69978) clip_id:  0001-0400/clip_266
# (pid=69961) video_to_frames done!!
# (pid=69961) json_to_info done!!
#   0%|          | 0/1891 [00:00<?, ?it/s]
# (pid=69961) ./result/0001-0400/clip_276.jsonpickle
# 100%|██████████| 1891/1891 [00:00<00:00, 37225.05it/s]
# (pid=69961) clip_id:  0001-0400/clip_277
# (pid=69992) video_to_frames done!!
# (pid=69992) json_to_info done!!
#   0%|          | 0/1472 [00:00<?, ?it/s]
# (pid=69992) ./result/0001-0400/clip_348.jsonpickle
# (pid=69992) clip_id:  0001-0400/clip_349
# 100%|██████████| 1472/1472 [00:00<00:00, 23864.99it/s]
# (pid=70000) video_to_frames done!!
# (pid=70000) json_to_info done!!
#   0%|          | 0/1560 [00:00<?, ?it/s]
# (pid=70000) ./result/0001-0400/clip_272.jsonpickle
# (pid=70000) clip_id:  0001-0400/clip_273
# 100%|██████████| 1560/1560 [00:00<00:00, 43599.83it/s]
# (pid=69995) video_to_frames done!!
# (pid=69995) json_to_info done!!
#   0%|          | 0/1599 [00:00<?, ?it/s]
# (pid=69995) ./result/0001-0400/clip_380.jsonpickle
# 100%|██████████| 1599/1599 [00:00<00:00, 27196.86it/s]
# (pid=69995) clip_id:  0001-0400/clip_381
# (pid=70010) video_to_frames done!!
# (pid=70010) json_to_info done!!
#   0%|          | 0/1520 [00:00<?, ?it/s]
# (pid=69952) video_to_frames done!!
# (pid=70010) ./result/0001-0400/clip_247.jsonpickle
# 100%|██████████| 1520/1520 [00:00<00:00, 23537.41it/s]
# (pid=70010) clip_id:  0001-0400/clip_248
# (pid=69952) json_to_info done!!
#   0%|          | 0/1630 [00:00<?, ?it/s]
# (pid=69952) ./result/0001-0400/clip_315.jsonpickle
# (pid=69952) clip_id:  0001-0400/clip_316
# 100%|██████████| 1630/1630 [00:00<00:00, 49674.60it/s]
# (pid=70001) video_to_frames done!!
# (pid=70001) json_to_info done!!
#   0%|          | 0/1826 [00:00<?, ?it/s]
# (pid=70001) ./result/0001-0400/clip_102.jsonpickle
# (pid=70001) clip_id:  0001-0400/clip_103
# 100%|██████████| 1826/1826 [00:00<00:00, 26748.15it/s]
# (pid=69983) video_to_frames done!!
# (pid=69983) json_to_info done!!
# (pid=70011) video_to_frames done!!
#   0%|          | 0/1609 [00:00<?, ?it/s]
# (pid=69943) video_to_frames done!!
# (pid=69983) ./result/0001-0400/clip_326.jsonpickle
# (pid=69983) clip_id:  0001-0400/clip_327
# 100%|██████████| 1609/1609 [00:00<00:00, 29099.36it/s]
# (pid=69943) json_to_info done!!
#   0%|          | 0/1679 [00:00<?, ?it/s]
# (pid=70011) json_to_info done!!
# (pid=69943) ./result/0001-0400/clip_269.jsonpickle
# 100%|██████████| 1679/1679 [00:00<00:00, 29904.48it/s]
#   0%|          | 0/1698 [00:00<?, ?it/s]
# (pid=69943) clip_id:  0001-0400/clip_27
# (pid=70011) ./result/0001-0400/clip_236.jsonpickle
# 100%|██████████| 1698/1698 [00:00<00:00, 24331.59it/s]
# (pid=70011) clip_id:  0001-0400/clip_237
# (pid=70004) video_to_frames done!!
# (pid=70004) json_to_info done!!
#   0%|          | 0/761 [00:00<?, ?it/s]
# (pid=70004) ./result/0001-0400/clip_143.jsonpickle
# (pid=70004) clip_id:  0001-0400/clip_144
# 100%|██████████| 761/761 [00:00<00:00, 19925.75it/s]
# (pid=69939) video_to_frames done!!
# (pid=69939) json_to_info done!!
#   0%|          | 0/1755 [00:00<?, ?it/s]
#  12%|█▏        | 209/1755 [00:00<00:00, 1852.55it/s]
# (pid=69939) ./result/0001-0400/clip_225.jsonpickle
# (pid=69939) clip_id:  0001-0400/clip_226
# 100%|██████████| 1755/1755 [00:00<00:00, 10155.57it/s]
# (pid=69947) video_to_frames done!!
# (pid=69930) video_to_frames done!!
# (pid=69930) json_to_info done!!
#   0%|          | 0/870 [00:00<?, ?it/s]
# (pid=69947) json_to_info done!!
# (pid=69930) ./result/0001-0400/clip_198.jsonpickle
# (pid=69930) clip_id:  0001-0400/clip_199
# 100%|██████████| 870/870 [00:00<00:00, 39459.37it/s]
#   0%|          | 0/1654 [00:00<?, ?it/s]
# (pid=69947) ./result/0001-0400/clip_290.jsonpickle
# (pid=69947) clip_id:  0001-0400/clip_291
# 100%|██████████| 1654/1654 [00:00<00:00, 21196.75it/s]
# (pid=69999) video_to_frames done!!
# (pid=69999) json_to_info done!!
#   0%|          | 0/1654 [00:00<?, ?it/s]
# (pid=69999) ./result/0001-0400/clip_322.jsonpickle
# (pid=69999) clip_id:  0001-0400/clip_323
# 100%|██████████| 1654/1654 [00:00<00:00, 25631.63it/s]
# (pid=69981) video_to_frames done!!
# (pid=69985) video_to_frames done!!
# (pid=69981) json_to_info done!!
# (pid=69985) json_to_info done!!
# (pid=69981) ./result/0001-0400/clip_168.jsonpickle
# (pid=69981) clip_id:  0001-0400/clip_169
# 100%|██████████| 1663/1663 [00:00<00:00, 52558.38it/s]
# (pid=69985) ./result/0001-0400/clip_298.jsonpickle
# 100%|██████████| 1918/1918 [00:00<00:00, 52766.15it/s]
# (pid=69985) clip_id:  0001-0400/clip_299
# (pid=69937) video_to_frames done!!
# (pid=69937) json_to_info done!!
#   0%|          | 0/1393 [00:00<?, ?it/s]
# (pid=69937) ./result/0001-0400/clip_182.jsonpickle
# (pid=69937) clip_id:  0001-0400/clip_183
# 100%|██████████| 1393/1393 [00:00<00:00, 45984.96it/s]
# (pid=69956) video_to_frames done!!
# (pid=69956) json_to_info done!!
#   0%|          | 0/1498 [00:00<?, ?it/s]
# (pid=69956) ./result/0001-0400/clip_258.jsonpickle
# (pid=69956) clip_id:  0001-0400/clip_259
# 100%|██████████| 1498/1498 [00:00<00:00, 25379.57it/s]
# (pid=69931) video_to_frames done!!
# (pid=69951) video_to_frames done!!
# (pid=69931) json_to_info done!!
#   0%|          | 0/1933 [00:00<?, ?it/s]
# (pid=69931) ./result/0001-0400/clip_333.jsonpickle
# 100%|██████████| 1933/1933 [00:00<00:00, 29964.63it/s]
# (pid=69951) json_to_info done!!
# (pid=69931) clip_id:  0001-0400/clip_334
#   0%|          | 0/1888 [00:00<?, ?it/s]
# (pid=69951) ./result/0001-0400/clip_359.jsonpickle
# 100%|██████████| 1888/1888 [00:00<00:00, 32479.18it/s]
# (pid=69951) clip_id:  0001-0400/clip_36
# (pid=70006) video_to_frames done!!
# (pid=70006) json_to_info done!!
#   0%|          | 0/978 [00:00<?, ?it/s]
# (pid=70006) ./result/0001-0400/clip_154.jsonpickle
# (pid=70006) clip_id:  0001-0400/clip_155
# 100%|██████████| 978/978 [00:00<00:00, 27682.93it/s]
# (pid=69977) video_to_frames done!!
# (pid=69977) json_to_info done!!
#   0%|          | 0/1921 [00:00<?, ?it/s]
# (pid=69977) ./result/0001-0400/clip_337.jsonpickle
# (pid=69977) clip_id:  0001-0400/clip_338
# 100%|██████████| 1921/1921 [00:00<00:00, 46079.39it/s]
# (pid=70008) video_to_frames done!!
# (pid=70008) json_to_info done!!
#   0%|          | 0/1824 [00:00<?, ?it/s]
# (pid=70008) ./result/0001-0400/clip_300.jsonpickle
# (pid=70008) clip_id:  0001-0400/clip_301
# 100%|██████████| 1824/1824 [00:00<00:00, 27677.56it/s]
# (pid=69982) video_to_frames done!!
# (pid=69982) json_to_info done!!
#   0%|          | 0/1950 [00:00<?, ?it/s]
# (pid=69982) ./result/0001-0400/clip_355.jsonpickle
# 100%|██████████| 1950/1950 [00:00<00:00, 38169.18it/s]
# (pid=69982) clip_id:  0001-0400/clip_356
# (pid=70003) video_to_frames done!!
# (pid=70003) json_to_info done!!
#   0%|          | 0/2181 [00:00<?, ?it/s]
# (pid=70003) ./result/0001-0400/clip_319.jsonpickle
# 100%|██████████| 2181/2181 [00:00<00:00, 30934.02it/s]
# (pid=70003) clip_id:  0001-0400/clip_32
# (pid=69942) video_to_frames done!!
# (pid=69932) video_to_frames done!!
# (pid=69932) json_to_info done!!
#   0%|          | 0/998 [00:00<?, ?it/s]
# (pid=69932) ./result/0001-0400/clip_200.jsonpickle
# (pid=69932) clip_id:  0001-0400/clip_201
# 100%|██████████| 998/998 [00:00<00:00, 29076.73it/s]
# (pid=69942) json_to_info done!!
#   0%|          | 0/2048 [00:00<?, ?it/s]
# (pid=69942) ./result/0001-0400/clip_351.jsonpickle
# (pid=69942) clip_id:  0001-0400/clip_352
# 100%|██████████| 2048/2048 [00:00<00:00, 26071.90it/s]
# (pid=69971) video_to_frames done!!
# (pid=69971) json_to_info done!!
#   0%|          | 0/888 [00:00<?, ?it/s]
# (pid=69971) ./result/0001-0400/clip_150.jsonpickle
# (pid=69971) clip_id:  0001-0400/clip_151
# 100%|██████████| 888/888 [00:00<00:00, 5319.22it/s]
# (pid=69936) video_to_frames done!!
# (pid=69976) video_to_frames done!!
# (pid=69936) json_to_info done!!
#   0%|          | 0/1142 [00:00<?, ?it/s]
# (pid=69936) ./result/0001-0400/clip_147.jsonpickle
# (pid=69936) clip_id:  0001-0400/clip_148
# 100%|██████████| 1142/1142 [00:00<00:00, 19801.06it/s]
# (pid=69976) json_to_info done!!
#   0%|          | 0/2269 [00:00<?, ?it/s]
# (pid=69976) ./result/0001-0400/clip_311.jsonpickle
# 100%|██████████| 2269/2269 [00:00<00:00, 34005.72it/s]
# (pid=69976) clip_id:  0001-0400/clip_312
# (pid=69996) video_to_frames done!!
# (pid=69996) json_to_info done!!
#   0%|          | 0/790 [00:00<?, ?it/s]
# (pid=69996) ./result/0001-0400/clip_107.jsonpickle
# 100%|██████████| 790/790 [00:00<00:00, 36440.92it/s]
# (pid=69996) clip_id:  0001-0400/clip_108
# (pid=69957) video_to_frames done!!
# (pid=69957) json_to_info done!!
#   0%|          | 0/2101 [00:00<?, ?it/s]
# (pid=69957) ./result/0001-0400/clip_340.jsonpickle
# (pid=69957) clip_id:  0001-0400/clip_341
# 100%|██████████| 2101/2101 [00:00<00:00, 27020.45it/s]
# (pid=69989) video_to_frames done!!
# (pid=69989) json_to_info done!!
#   0%|          | 0/1223 [00:00<?, ?it/s]
# (pid=69989) ./result/0001-0400/clip_120.jsonpickle
# (pid=69989) clip_id:  0001-0400/clip_121
# 100%|██████████| 1223/1223 [00:00<00:00, 21722.76it/s]
# (pid=69973) video_to_frames done!!
# (pid=69973) json_to_info done!!
# (pid=69973) ./result/0001-0400/clip_194.jsonpickle
# (pid=69973) clip_id:  0001-0400/clip_195
# 100%|██████████| 741/741 [00:00<00:00, 37274.43it/s]
# (pid=70014) video_to_frames done!!
# (pid=70014) json_to_info done!!
#   0%|          | 0/2367 [00:00<?, ?it/s]
# (pid=70014) ./result/0001-0400/clip_135.jsonpickle
# (pid=70014) clip_id:  0001-0400/clip_136
# 100%|██████████| 2367/2367 [00:00<00:00, 28243.47it/s]
# (pid=69955) video_to_frames done!!
# (pid=69955) json_to_info done!!
#   0%|          | 0/1156 [00:00<?, ?it/s]
# (pid=69955) ./result/0001-0400/clip_110.jsonpickle
# (pid=69955) clip_id:  0001-0400/clip_111
# 100%|██████████| 1156/1156 [00:00<00:00, 46912.70it/s]
# (pid=69965) video_to_frames done!!
# (pid=69965) json_to_info done!!
# (pid=69965) ./result/0001-0400/clip_187.jsonpickle
# (pid=69965) clip_id:  0001-0400/clip_188
# 100%|██████████| 845/845 [00:00<00:00, 33031.25it/s]
# (pid=69984) video_to_frames done!!
# (pid=69984) json_to_info done!!
#   0%|          | 0/2548 [00:00<?, ?it/s]
# (pid=69984) ./result/0001-0400/clip_131.jsonpickle
# (pid=69984) clip_id:  0001-0400/clip_132
# 100%|██████████| 2548/2548 [00:00<00:00, 51774.26it/s]
# (pid=69968) video_to_frames done!!
# (pid=69994) video_to_frames done!!
# (pid=69994) json_to_info done!!
# (pid=69968) json_to_info done!!
#   0%|          | 0/1592 [00:00<?, ?it/s]
# (pid=69994) ./result/0001-0400/clip_158.jsonpickle
# (pid=69994) clip_id:  0001-0400/clip_159
# 100%|██████████| 1260/1260 [00:00<00:00, 43700.78it/s]
# (pid=69968) ./result/0001-0400/clip_10.jsonpickle
# 100%|██████████| 1592/1592 [00:00<00:00, 25769.17it/s]
# (pid=69968) clip_id:  0001-0400/clip_100
# (pid=69980) video_to_frames done!!
# (pid=69980) json_to_info done!!
#   0%|          | 0/1222 [00:00<?, ?it/s]
# (pid=69980) ./result/0001-0400/clip_118.jsonpickle
# (pid=69980) clip_id:  0001-0400/clip_119
# 100%|██████████| 1222/1222 [00:00<00:00, 34285.71it/s]
# (pid=69934) video_to_frames done!!
# (pid=69934) json_to_info done!!
# (pid=69934) ./result/0001-0400/clip_219.jsonpickle
# 100%|██████████| 1123/1123 [00:00<00:00, 22475.24it/s]
# (pid=69934) clip_id:  0001-0400/clip_22
# (pid=69993) video_to_frames done!!
# (pid=69993) json_to_info done!!
#   0%|          | 0/2126 [00:00<?, ?it/s]
#  26%|██▋       | 559/2126 [00:00<00:00, 4889.81it/s]
# (pid=69993) ./result/0001-0400/clip_124.jsonpickle
# (pid=69993) clip_id:  0001-0400/clip_125
# 100%|██████████| 2126/2126 [00:00<00:00, 11550.68it/s]
# (pid=69940) video_to_frames done!!
# (pid=69940) json_to_info done!!
#   0%|          | 0/1305 [00:00<?, ?it/s]
# (pid=69940) ./result/0001-0400/clip_367.jsonpickle
# (pid=69940) clip_id:  0001-0400/clip_368
# 100%|██████████| 1305/1305 [00:00<00:00, 27442.20it/s]
# (pid=69974) video_to_frames done!!
# (pid=69974) json_to_info done!!
#   0%|          | 0/1073 [00:00<?, ?it/s]
# (pid=69974) ./result/0001-0400/clip_114.jsonpickle
# 100%|██████████| 1073/1073 [00:00<00:00, 36028.12it/s]
# (pid=69974) clip_id:  0001-0400/clip_115
# (pid=69972) video_to_frames done!!
# (pid=69972) json_to_info done!!
# (pid=69972) ./result/0001-0400/clip_215.jsonpickle
# 100%|██████████| 945/945 [00:00<00:00, 34337.84it/s]
# (pid=69972) clip_id:  0001-0400/clip_216
# (pid=69990) video_to_frames done!!
# (pid=69990) json_to_info done!!
# (pid=69990) ./result/0001-0400/clip_161.jsonpickle
# (pid=69990) clip_id:  0001-0400/clip_162
# 100%|██████████| 1514/1514 [00:00<00:00, 47974.01it/s]
# (pid=70013) video_to_frames done!!
# (pid=70013) json_to_info done!!
#   0%|          | 0/2773 [00:00<?, ?it/s]
# (pid=70013) ./result/0001-0400/clip_128.jsonpickle
# 100%|██████████| 2773/2773 [00:00<00:00, 45464.44it/s]
# (pid=70013) clip_id:  0001-0400/clip_129
# (pid=69959) video_to_frames done!!
# (pid=69959) json_to_info done!!
#   0%|          | 0/1364 [00:00<?, ?it/s]
# (pid=69959) ./result/0001-0400/clip_240.jsonpickle
# (pid=69959) clip_id:  0001-0400/clip_241
# 100%|██████████| 1364/1364 [00:00<00:00, 27314.28it/s]
# (pid=70004) video_to_frames done!!
# (pid=70004) json_to_info done!!
# (pid=70004) ./result/0001-0400/clip_144.jsonpickle
# (pid=70004) clip_id:  0001-0400/clip_145
# 100%|██████████| 974/974 [00:00<00:00, 32917.97it/s]
# (pid=70012) video_to_frames done!!
# (pid=70012) json_to_info done!!
# (pid=70012) ./result/0001-0400/clip_190.jsonpickle
# 100%|██████████| 1274/1274 [00:00<00:00, 33892.40it/s]
# (pid=70012) clip_id:  0001-0400/clip_191
# (pid=69958) video_to_frames done!!
# (pid=69958) json_to_info done!!
#   0%|          | 0/1011 [00:00<?, ?it/s]
# (pid=69958) ./result/0001-0400/clip_233.jsonpickle
# (pid=69958) clip_id:  0001-0400/clip_234
# 100%|██████████| 1011/1011 [00:00<00:00, 33223.19it/s]
# (pid=70009) video_to_frames done!!
# (pid=70009) json_to_info done!!
#   0%|          | 0/1458 [00:00<?, ?it/s]
# (pid=70009) ./result/0001-0400/clip_374.jsonpickle
# (pid=70009) clip_id:  0001-0400/clip_375
# 100%|██████████| 1458/1458 [00:00<00:00, 25612.94it/s]
# (pid=69933) video_to_frames done!!
# (pid=69933) json_to_info done!!
#   0%|          | 0/1369 [00:00<?, ?it/s]
# (pid=69933) ./result/0001-0400/clip_244.jsonpickle
# 100%|██████████| 1369/1369 [00:00<00:00, 28098.31it/s]
# (pid=69933) clip_id:  0001-0400/clip_245
# (pid=69988) video_to_frames done!!
# (pid=69988) json_to_info done!!
#   0%|          | 0/1519 [00:00<?, ?it/s]
# (pid=69988) ./result/0001-0400/clip_18.jsonpickle
# (pid=69988) clip_id:  0001-0400/clip_180
# 100%|██████████| 1519/1519 [00:00<00:00, 24974.51it/s]
# (pid=69935) video_to_frames done!!
# (pid=69935) json_to_info done!!
#   0%|          | 0/1313 [00:00<?, ?it/s]
# (pid=69935) ./result/0001-0400/clip_284.jsonpickle
# (pid=69935) clip_id:  0001-0400/clip_285
# 100%|██████████| 1313/1313 [00:00<00:00, 33135.51it/s]
# (pid=69945) video_to_frames done!!
# (pid=69945) json_to_info done!!
#   0%|          | 0/1215 [00:00<?, ?it/s]
# (pid=69945) ./result/0001-0400/clip_251.jsonpickle
# (pid=69945) clip_id:  0001-0400/clip_252
# 100%|██████████| 1215/1215 [00:00<00:00, 31477.88it/s]
# (pid=70010) video_to_frames done!!
# (pid=70010) json_to_info done!!
# (pid=70010) ./result/0001-0400/clip_248.jsonpickle
# 100%|██████████| 1061/1061 [00:00<00:00, 30083.26it/s]
# (pid=70010) clip_id:  0001-0400/clip_249
# (pid=69954) video_to_frames done!!
# (pid=69954) json_to_info done!!
#   0%|          | 0/1706 [00:00<?, ?it/s]
# (pid=69954) ./result/0001-0400/clip_345.jsonpickle
# (pid=69954) clip_id:  0001-0400/clip_346
# 100%|██████████| 1706/1706 [00:00<00:00, 27243.21it/s]
# (pid=70006) video_to_frames done!!
# (pid=70006) json_to_info done!!
# (pid=69997) video_to_frames done!!
# (pid=70006) ./result/0001-0400/clip_155.jsonpickle
# (pid=70006) clip_id:  0001-0400/clip_156
# 100%|██████████| 821/821 [00:00<00:00, 37092.55it/s]
# (pid=69997) json_to_info done!!
# (pid=69997) ./result/0001-0400/clip_262.jsonpickle
# 100%|██████████| 1210/1210 [00:00<00:00, 34436.93it/s]
# (pid=69997) clip_id:  0001-0400/clip_263
# (pid=70005) video_to_frames done!!
# (pid=70005) json_to_info done!!
# (pid=70005) ./result/0001-0400/clip_14.jsonpickle
# (pid=70005) clip_id:  0001-0400/clip_140
# 100%|██████████| 616/616 [00:00<00:00, 35626.31it/s]
# (pid=70001) video_to_frames done!!
# (pid=69961) video_to_frames done!!
# (pid=69961) json_to_info done!!
#   0%|          | 0/1168 [00:00<?, ?it/s]
# (pid=70001) json_to_info done!!
# (pid=70001) ./result/0001-0400/clip_103.jsonpickle
# (pid=70001) clip_id:  0001-0400/clip_104
# 100%|██████████| 1194/1194 [00:00<00:00, 47759.82it/s]
# (pid=69961) ./result/0001-0400/clip_277.jsonpickle
# (pid=69961) clip_id:  0001-0400/clip_278
# 100%|██████████| 1168/1168 [00:00<00:00, 24390.71it/s]
# (pid=69979) video_to_frames done!!
# (pid=69943) video_to_frames done!!
# (pid=69979) json_to_info done!!
# (pid=69943) json_to_info done!!
# (pid=69943) ./result/0001-0400/clip_27.jsonpickle
# 100%|██████████| 1072/1072 [00:00<00:00, 34411.11it/s]
# (pid=69979) ./result/0001-0400/clip_370.jsonpickle
# 100%|██████████| 1367/1367 [00:00<00:00, 26664.62it/s]
# (pid=69943) clip_id:  0001-0400/clip_270
# (pid=69979) clip_id:  0001-0400/clip_371
# (pid=69998) video_to_frames done!!
# (pid=69998) json_to_info done!!
#   0%|          | 0/1498 [00:00<?, ?it/s]
# (pid=69998) ./result/0001-0400/clip_255.jsonpickle
# 100%|██████████| 1498/1498 [00:00<00:00, 20742.97it/s]
# (pid=69998) clip_id:  0001-0400/clip_256
# (pid=69949) video_to_frames done!!
# (pid=69949) json_to_info done!!
#   0%|          | 0/1476 [00:00<?, ?it/s]
# (pid=69949) ./result/0001-0400/clip_363.jsonpickle
# (pid=69949) clip_id:  0001-0400/clip_364
# 100%|██████████| 1476/1476 [00:00<00:00, 43795.75it/s]
# (pid=69986) video_to_frames done!!
# (pid=69986) json_to_info done!!
#   0%|          | 0/1439 [00:00<?, ?it/s]
# (pid=69986) ./result/0001-0400/clip_204.jsonpickle
# (pid=69986) clip_id:  0001-0400/clip_205
# 100%|██████████| 1439/1439 [00:00<00:00, 39380.69it/s]
# (pid=69948) video_to_frames done!!
# (pid=69948) json_to_info done!!
#   0%|          | 0/1687 [00:00<?, ?it/s]
# (pid=69948) ./result/0001-0400/clip_172.jsonpickle
# 100%|██████████| 1687/1687 [00:00<00:00, 33197.70it/s]
# (pid=69948) clip_id:  0001-0400/clip_173
# (pid=69938) video_to_frames done!!
# (pid=69938) json_to_info done!!
#   0%|          | 0/1753 [00:00<?, ?it/s]
# (pid=69938) ./result/0001-0400/clip_208.jsonpickle
# (pid=69938) clip_id:  0001-0400/clip_209
# 100%|██████████| 1753/1753 [00:00<00:00, 47644.01it/s]
# (pid=69941) video_to_frames done!!
# (pid=70007) video_to_frames done!!
# (pid=69941) json_to_info done!!
#   0%|          | 0/1504 [00:00<?, ?it/s]
# (pid=69941) ./result/0001-0400/clip_23.jsonpickle
# (pid=69941) clip_id:  0001-0400/clip_230
# 100%|██████████| 1504/1504 [00:00<00:00, 28024.76it/s]
# (pid=70007) json_to_info done!!
#   0%|          | 0/1815 [00:00<?, ?it/s]
# (pid=70002) video_to_frames done!!
# (pid=70007) ./result/0001-0400/clip_176.jsonpickle
# (pid=70007) clip_id:  0001-0400/clip_177
# 100%|██████████| 1815/1815 [00:00<00:00, 24403.00it/s]
# (pid=70002) json_to_info done!!
#   0%|          | 0/1413 [00:00<?, ?it/s]
# (pid=70002) ./result/0001-0400/clip_385.jsonpickle
# (pid=70002) clip_id:  0001-0400/clip_386
# 100%|██████████| 1413/1413 [00:00<00:00, 44119.34it/s]
# (pid=70000) video_to_frames done!!
# (pid=70000) json_to_info done!!
#   0%|          | 0/1381 [00:00<?, ?it/s]
# (pid=70000) ./result/0001-0400/clip_273.jsonpickle
# (pid=70000) clip_id:  0001-0400/clip_274
# 100%|██████████| 1381/1381 [00:00<00:00, 24785.87it/s]
# (pid=69981) video_to_frames done!!
# (pid=69981) json_to_info done!!
# (pid=69981) ./result/0001-0400/clip_169.jsonpickle
# (pid=69981) clip_id:  0001-0400/clip_17
# 100%|██████████| 1220/1220 [00:00<00:00, 46877.47it/s]
# (pid=69950) video_to_frames done!!
# (pid=69950) json_to_info done!!
# (pid=69950) ./result/0001-0400/clip_305.jsonpickle
# 100%|██████████| 1603/1603 [00:00<00:00, 47879.09it/s]
# (pid=69950) clip_id:  0001-0400/clip_306
# (pid=69936) video_to_frames done!!
# (pid=69936) json_to_info done!!
#   0%|          | 0/993 [00:00<?, ?it/s]
# (pid=69936) ./result/0001-0400/clip_148.jsonpickle
# (pid=69936) clip_id:  0001-0400/clip_149
# 100%|██████████| 993/993 [00:00<00:00, 29488.83it/s]
# (pid=69946) video_to_frames done!!
# (pid=69946) json_to_info done!!
#   0%|          | 0/2105 [00:00<?, ?it/s]
# (pid=69946) ./result/0001-0400/clip_280.jsonpickle
# (pid=69946) clip_id:  0001-0400/clip_281
# 100%|██████████| 2105/2105 [00:00<00:00, 38321.02it/s]
# (pid=69962) video_to_frames done!!
# (pid=69962) json_to_info done!!
#   0%|          | 0/1992 [00:00<?, ?it/s]
# (pid=69962) ./result/0001-0400/clip_330.jsonpickle
# 100%|██████████| 1992/1992 [00:00<00:00, 42269.61it/s]
# (pid=69962) clip_id:  0001-0400/clip_331
# (pid=69939) video_to_frames done!!
# (pid=69932) video_to_frames done!!
# (pid=69987) video_to_frames done!!
# (pid=69932) json_to_info done!!
# (pid=69939) json_to_info done!!
#   0%|          | 0/1473 [00:00<?, ?it/s]
# (pid=69932) ./result/0001-0400/clip_201.jsonpickle
# (pid=69932) clip_id:  0001-0400/clip_202
# 100%|██████████| 1129/1129 [00:00<00:00, 35891.14it/s]
# (pid=69939) ./result/0001-0400/clip_226.jsonpickle
# 100%|██████████| 1473/1473 [00:00<00:00, 34524.01it/s]
# (pid=69939) clip_id:  0001-0400/clip_227
# (pid=69987) json_to_info done!!
#   0%|          | 0/1683 [00:00<?, ?it/s]
# (pid=69987) ./result/0001-0400/clip_165.jsonpickle
# (pid=69987) clip_id:  0001-0400/clip_166
# 100%|██████████| 1683/1683 [00:00<00:00, 23459.04it/s]
# (pid=69930) video_to_frames done!!
# (pid=69971) video_to_frames done!!
# (pid=69930) json_to_info done!!
#   0%|          | 0/1252 [00:00<?, ?it/s]
# (pid=69930) ./result/0001-0400/clip_199.jsonpickle
# 100%|██████████| 1252/1252 [00:00<00:00, 31593.80it/s]
# (pid=69930) clip_id:  0001-0400/clip_2
# (pid=69971) json_to_info done!!
#   0%|          | 0/1047 [00:00<?, ?it/s]
# (pid=69971) ./result/0001-0400/clip_151.jsonpickle
# (pid=69971) clip_id:  0001-0400/clip_152
# 100%|██████████| 1047/1047 [00:00<00:00, 27921.49it/s]
# (pid=69970) video_to_frames done!!
# (pid=69970) json_to_info done!!
# (pid=69970) ./result/0001-0400/clip_378.jsonpickle
# 100%|██████████| 1744/1744 [00:00<00:00, 50734.62it/s]
# (pid=69970) clip_id:  0001-0400/clip_379
# (pid=69969) video_to_frames done!!
# (pid=69975) video_to_frames done!!
# (pid=69991) video_to_frames done!!
# (pid=69969) json_to_info done!!
#   0%|          | 0/1748 [00:00<?, ?it/s]
# (pid=69969) ./result/0001-0400/clip_309.jsonpickle
# 100%|██████████| 1748/1748 [00:00<00:00, 44024.64it/s]
# (pid=69969) clip_id:  0001-0400/clip_31
# (pid=69975) json_to_info done!!
#   0%|          | 0/2178 [00:00<?, ?it/s]
# (pid=69991) json_to_info done!!
# (pid=69975) ./result/0001-0400/clip_222.jsonpickle
# 100%|██████████| 2178/2178 [00:00<00:00, 36113.91it/s]
#   0%|          | 0/1851 [00:00<?, ?it/s]
# (pid=69991) ./result/0001-0400/clip_295.jsonpickle
# (pid=69991) clip_id:  0001-0400/clip_296
# 100%|██████████| 1851/1851 [00:00<00:00, 47715.27it/s]
# (pid=69975) clip_id:  0001-0400/clip_223
# (pid=69978) video_to_frames done!!
# (pid=69944) video_to_frames done!!
# (pid=69951) video_to_frames done!!
# (pid=69978) json_to_info done!!
#   0%|          | 0/1573 [00:00<?, ?it/s]
# (pid=69978) ./result/0001-0400/clip_266.jsonpickle
# (pid=69978) clip_id:  0001-0400/clip_267
# 100%|██████████| 1573/1573 [00:00<00:00, 40060.48it/s]
# (pid=69951) json_to_info done!!
#   0%|          | 0/1413 [00:00<?, ?it/s]
# (pid=69944) json_to_info done!!
#   0%|          | 0/1386 [00:00<?, ?it/s]
# (pid=69951) ./result/0001-0400/clip_36.jsonpickle
# (pid=69951) clip_id:  0001-0400/clip_360
# 100%|██████████| 1413/1413 [00:00<00:00, 25552.42it/s]
# (pid=69944) ./result/0001-0400/clip_211.jsonpickle
# (pid=69944) clip_id:  0001-0400/clip_212
# 100%|██████████| 1386/1386 [00:00<00:00, 28772.61it/s]
# (pid=69996) video_to_frames done!!
# (pid=69996) json_to_info done!!
# (pid=69996) ./result/0001-0400/clip_108.jsonpickle
# 100%|██████████| 1085/1085 [00:00<00:00, 32578.93it/s]
# (pid=69996) clip_id:  0001-0400/clip_109
# (pid=69960) video_to_frames done!!
# (pid=69960) json_to_info done!!
#   0%|          | 0/1478 [00:00<?, ?it/s]
# (pid=69960) ./result/0001-0400/clip_288.jsonpickle
# (pid=69960) clip_id:  0001-0400/clip_289
# 100%|██████████| 1478/1478 [00:00<00:00, 33862.91it/s]
# (pid=69937) video_to_frames done!!
# (pid=69947) video_to_frames done!!
# (pid=69937) json_to_info done!!
#   0%|          | 0/1401 [00:00<?, ?it/s]
# (pid=69937) ./result/0001-0400/clip_183.jsonpickle
# (pid=69937) clip_id:  0001-0400/clip_184
# 100%|██████████| 1401/1401 [00:00<00:00, 42930.97it/s]
# (pid=69947) json_to_info done!!
# (pid=69947) ./result/0001-0400/clip_291.jsonpickle
# (pid=69947) clip_id:  0001-0400/clip_292
# 100%|██████████| 1513/1513 [00:00<00:00, 50824.78it/s]
# (pid=69956) video_to_frames done!!
# (pid=69956) json_to_info done!!
#   0%|          | 0/1387 [00:00<?, ?it/s]
# (pid=69956) ./result/0001-0400/clip_259.jsonpickle
# (pid=69956) clip_id:  0001-0400/clip_26
# 100%|██████████| 1387/1387 [00:00<00:00, 30281.02it/s]
# (pid=69999) video_to_frames done!!
# (pid=69999) json_to_info done!!
#   0%|          | 0/1590 [00:00<?, ?it/s]
# (pid=69999) ./result/0001-0400/clip_323.jsonpickle
# 100%|██████████| 1590/1590 [00:00<00:00, 27950.54it/s]
# (pid=69999) clip_id:  0001-0400/clip_324
# (pid=69995) video_to_frames done!!
# (pid=69995) json_to_info done!!
#   0%|          | 0/1761 [00:00<?, ?it/s]
# (pid=69995) ./result/0001-0400/clip_381.jsonpickle
# (pid=69995) clip_id:  0001-0400/clip_382
# 100%|██████████| 1761/1761 [00:00<00:00, 49594.24it/s]
# (pid=69983) video_to_frames done!!
# (pid=69983) json_to_info done!!
#   0%|          | 0/1713 [00:00<?, ?it/s]
# ...
# 100%|██████████| 1500/1500 [00:00<00:00, 63741.28it/s]
# (pid=69999) video_to_frames done!!
# (pid=69999) json_to_info done!!
#   0%|          | 0/1950 [00:00<?, ?it/s]
# (pid=69999) ./result/0001-0400/clip_325.jsonpickle
# 100%|██████████| 1950/1950 [00:00<00:00, 52984.46it/s]
# (pid=70008) video_to_frames done!!
# (pid=70008) json_to_info done!!
#   0%|          | 0/1650 [00:00<?, ?it/s]
# (pid=70008) ./result/0001-0400/clip_303.jsonpickle
# 100%|██████████| 1650/1650 [00:00<00:00, 54829.68it/s]
# (pid=69991) video_to_frames done!!
# (pid=69991) json_to_info done!!
#   0%|          | 0/1724 [00:00<?, ?it/s]
# (pid=69991) ./result/0001-0400/clip_297.jsonpickle
# 100%|██████████| 1724/1724 [00:00<00:00, 72179.16it/s]
# (pid=70003) video_to_frames done!!
# (pid=70003) json_to_info done!!
# (pid=70003) ./result/0001-0400/clip_321.jsonpickle
# 100%|██████████| 1462/1462 [00:00<00:00, 66404.67it/s]
# (pid=69931) video_to_frames done!!
# (pid=69931) json_to_info done!!
# (pid=69931) ./result/0001-0400/clip_336.jsonpickle
# 100%|██████████| 1799/1799 [00:00<00:00, 61597.36it/s]
# (pid=70014) video_to_frames done!!
# (pid=69951) video_to_frames done!!
# (pid=69983) video_to_frames done!!
# (pid=70014) json_to_info done!!
#   0%|          | 0/3437 [00:00<?, ?it/s]
# (pid=70014) ./result/0001-0400/clip_137.jsonpickle
# (pid=70014) clip_id:  0001-0400/clip_138
# 100%|██████████| 3437/3437 [00:00<00:00, 79339.47it/s]
# (pid=69951) json_to_info done!!
# (pid=69951) ./result/0001-0400/clip_361.jsonpickle
# 100%|██████████| 2077/2077 [00:00<00:00, 74917.61it/s]
# (pid=69983) json_to_info done!!
#   0%|          | 0/1956 [00:00<?, ?it/s]
# (pid=69983) ./result/0001-0400/clip_329.jsonpickle
# 100%|██████████| 1956/1956 [00:00<00:00, 70439.24it/s]
# (pid=69974) video_to_frames done!!
# (pid=69974) json_to_info done!!
# (pid=69974) ./result/0001-0400/clip_71.jsonpickle
# (pid=69974) clip_id:  0001-0400/clip_72
# 100%|██████████| 1316/1316 [00:00<00:00, 83762.60it/s]
# (pid=69930) video_to_frames done!!
# (pid=69930) json_to_info done!!
# (pid=69930) ./result/0001-0400/clip_40.jsonpickle
# (pid=69930) clip_id:  0001-0400/clip_400
# 100%|██████████| 1088/1088 [00:00<00:00, 84237.59it/s]
# (pid=69994) video_to_frames done!!
# (pid=69994) json_to_info done!!
# (pid=69994) ./result/0001-0400/clip_60.jsonpickle
# 100%|██████████| 1402/1402 [00:00<00:00, 49480.11it/s]
# (pid=69994) clip_id:  0001-0400/clip_61
# (pid=69992) video_to_frames done!!
# (pid=69992) json_to_info done!!
# (pid=69992) ./result/0001-0400/clip_350.jsonpickle
# 100%|██████████| 2409/2409 [00:00<00:00, 55914.77it/s]
# (pid=69962) video_to_frames done!!
# (pid=69962) json_to_info done!!
#   0%|          | 0/2270 [00:00<?, ?it/s]
# (pid=69962) ./result/0001-0400/clip_332.jsonpickle
# 100%|██████████| 2270/2270 [00:00<00:00, 62265.03it/s]
# (pid=70009) video_to_frames done!!
# (pid=70009) json_to_info done!!
# (pid=70009) ./result/0001-0400/clip_75.jsonpickle
# 100%|██████████| 1006/1006 [00:00<00:00, 57300.95it/s]
# (pid=70009) clip_id:  0001-0400/clip_76
# (pid=70012) video_to_frames done!!
# (pid=70012) json_to_info done!!
# (pid=70012) ./result/0001-0400/clip_64.jsonpickle
# 100%|██████████| 1460/1460 [00:00<00:00, 80508.05it/s]
# (pid=70012) clip_id:  0001-0400/clip_65
# (pid=69996) video_to_frames done!!
# (pid=69996) json_to_info done!!
# (pid=69996) ./result/0001-0400/clip_42.jsonpickle
# (pid=69996) clip_id:  0001-0400/clip_43
# 0it [00:00, ?it/s]6)
# (pid=69990) video_to_frames done!!
# (pid=69990) json_to_info done!!
# (pid=69990) ./result/0001-0400/clip_68.jsonpickle
# 100%|██████████| 1499/1499 [00:00<00:00, 63907.28it/s]
# (pid=69990) clip_id:  0001-0400/clip_69
# (pid=69940) video_to_frames done!!
# (pid=69973) video_to_frames done!!
# (pid=69940) json_to_info done!!
# (pid=69940) ./result/0001-0400/clip_79.jsonpickle
# (pid=69940) clip_id:  0001-0400/clip_8
# 100%|██████████| 1266/1266 [00:00<00:00, 61416.27it/s]
# (pid=69973) json_to_info done!!
#   0%|          | 0/1674 [00:00<?, ?it/s]
# (pid=69973) ./result/0001-0400/clip_5.jsonpickle
# 100%|██████████| 1674/1674 [00:00<00:00, 55743.35it/s]
# (pid=69973) clip_id:  0001-0400/clip_50
# (pid=69977) video_to_frames done!!
# (pid=69957) video_to_frames done!!
# (pid=69977) json_to_info done!!
# (pid=69977) ./result/0001-0400/clip_34.jsonpickle
# 100%|██████████| 1478/1478 [00:00<00:00, 58945.51it/s]
# (pid=69957) json_to_info done!!
#   0%|          | 0/2094 [00:00<?, ?it/s]
# (pid=69957) ./result/0001-0400/clip_343.jsonpickle
# 100%|██████████| 2094/2094 [00:00<00:00, 78782.88it/s]
# (pid=70011) video_to_frames done!!
# (pid=70011) json_to_info done!!
#   0%|          | 0/2482 [00:00<?, ?it/s]
# (pid=70011) ./result/0001-0400/clip_239.jsonpickle
# 100%|██████████| 2482/2482 [00:00<00:00, 59888.64it/s]
# (pid=69965) video_to_frames done!!
# (pid=69965) json_to_info done!!
# (pid=69965) ./result/0001-0400/clip_82.jsonpickle
# 100%|██████████| 1230/1230 [00:00<00:00, 66453.62it/s]
# (pid=69965) clip_id:  0001-0400/clip_83
# (pid=69959) video_to_frames done!!
# (pid=69959) json_to_info done!!
# (pid=69959) ./result/0001-0400/clip_97.jsonpickle
# (pid=69959) clip_id:  0001-0400/clip_98
# 100%|██████████| 976/976 [00:00<00:00, 66594.67it/s]
# (pid=69998) video_to_frames done!!
# (pid=69998) json_to_info done!!
#   0%|          | 0/880 [00:00<?, ?it/s]
# (pid=69998) ./result/0001-0400/clip_9.jsonpickle
# (pid=69998) clip_id:  0001-0400/clip_90
# 100%|██████████| 880/880 [00:00<00:00, 61898.16it/s]
# (pid=69976) video_to_frames done!!
# (pid=69936) video_to_frames done!!
# (pid=69976) json_to_info done!!
#   0%|          | 0/2347 [00:00<?, ?it/s]
# (pid=69976) ./result/0001-0400/clip_314.jsonpickle
# 100%|██████████| 2347/2347 [00:00<00:00, 82548.15it/s]
# (pid=69936) json_to_info done!!
# (pid=69936) ./result/0001-0400/clip_397.jsonpickle
# (pid=69936) clip_id:  0001-0400/clip_398
# 100%|██████████| 1374/1374 [00:00<00:00, 85524.36it/s]
# (pid=69971) video_to_frames done!!
# (pid=69946) video_to_frames done!!
# (pid=69946) json_to_info done!!
# (pid=69946) ./result/0001-0400/clip_93.jsonpickle
# (pid=69946) clip_id:  0001-0400/clip_94
# 100%|██████████| 1145/1145 [00:00<00:00, 59771.72it/s]
# (pid=69971) json_to_info done!!
# (pid=69971) ./result/0001-0400/clip_57.jsonpickle
# (pid=69971) clip_id:  0001-0400/clip_58
# 100%|██████████| 1757/1757 [00:00<00:00, 74102.97it/s]
# (pid=69982) video_to_frames done!!
# (pid=69982) json_to_info done!!
#   0%|          | 0/1965 [00:00<?, ?it/s]
# (pid=69982) ./result/0001-0400/clip_358.jsonpickle
# 100%|██████████| 1965/1965 [00:00<00:00, 75670.53it/s]
# (pid=69955) video_to_frames done!!
# (pid=69955) json_to_info done!!
# (pid=69955) ./result/0001-0400/clip_86.jsonpickle
# (pid=69955) clip_id:  0001-0400/clip_87
# 100%|██████████| 1196/1196 [00:00<00:00, 79765.74it/s]
# (pid=69932) video_to_frames done!!
# (pid=69932) json_to_info done!!
# (pid=69932) ./result/0001-0400/clip_47.jsonpickle
# 100%|██████████| 1314/1314 [00:00<00:00, 66875.97it/s]
# (pid=69932) clip_id:  0001-0400/clip_48
# (pid=69980) video_to_frames done!!
# (pid=69980) json_to_info done!!
# (pid=69980) ./result/0001-0400/clip_53.jsonpickle
# 100%|██████████| 1504/1504 [00:00<00:00, 79828.82it/s]
# (pid=69980) clip_id:  0001-0400/clip_54
# (pid=69942) video_to_frames done!!
# (pid=69942) json_to_info done!!
#   0%|          | 0/2106 [00:00<?, ?it/s]
# (pid=69942) ./result/0001-0400/clip_354.jsonpickle
# 100%|██████████| 2106/2106 [00:00<00:00, 82469.30it/s]
# (pid=69993) video_to_frames done!!
# (pid=69993) json_to_info done!!
# 100%|██████████| 1855/1855 [00:00<00:00, 84823.48it/s]
# (pid=69993) ./result/0001-0400/clip_127.jsonpickle
# (pid=69993)
# (pid=69974) video_to_frames done!!
# (pid=69974) json_to_info done!!
#   0%|          | 0/934 [00:00<?, ?it/s]
# (pid=69974) ./result/0001-0400/clip_72.jsonpickle
# (pid=69974) clip_id:  0001-0400/clip_73
# 100%|██████████| 934/934 [00:00<00:00, 86677.58it/s]
# (pid=70006) video_to_frames done!!
# (pid=70006) json_to_info done!!
#   0%|          | 0/1384 [00:00<?, ?it/s]
# (pid=70006) ./result/0001-0400/clip_393.jsonpickle
# (pid=70006) clip_id:  0001-0400/clip_394
# 100%|██████████| 1384/1384 [00:00<00:00, 56429.09it/s]
# (pid=70004) video_to_frames done!!
# (pid=70004) json_to_info done!!
# (pid=70004) ./result/0001-0400/clip_39.jsonpickle
# 100%|██████████| 1523/1523 [00:00<00:00, 70646.48it/s]
# (pid=70004) clip_id:  0001-0400/clip_390
# (pid=69952) video_to_frames done!!
# (pid=69952) json_to_info done!!
#   0%|          | 0/2421 [00:00<?, ?it/s]
# (pid=69952) ./result/0001-0400/clip_318.jsonpickle
# 100%|██████████| 2421/2421 [00:00<00:00, 78715.75it/s]
# (pid=69994) video_to_frames done!!
# (pid=69994) json_to_info done!!
# (pid=69994) ./result/0001-0400/clip_61.jsonpickle
# (pid=69994) clip_id:  0001-0400/clip_62
# 100%|██████████| 1224/1224 [00:00<00:00, 87783.25it/s]
# (pid=70013) video_to_frames done!!
# (pid=70013) json_to_info done!!
#   0%|          | 0/2304 [00:00<?, ?it/s]
# (pid=70013) ./result/0001-0400/clip_130.jsonpickle
# 100%|██████████| 2304/2304 [00:00<00:00, 55635.57it/s]
# (pid=69965) video_to_frames done!!
# (pid=69965) json_to_info done!!
#   0%|          | 0/658 [00:00<?, ?it/s]
# (pid=69965) ./result/0001-0400/clip_83.jsonpickle
# 100%|██████████| 658/658 [00:00<00:00, 88366.16it/s]
# (pid=69965) clip_id:  0001-0400/clip_84
# (pid=69930) video_to_frames done!!
# (pid=69930) json_to_info done!!
# (pid=69930) ./result/0001-0400/clip_400.jsonpickle
# 100%|██████████| 1455/1455 [00:00<00:00, 63460.19it/s]
# (pid=69989) video_to_frames done!!
# (pid=69989) json_to_info done!!
#   0%|          | 0/2749 [00:00<?, ?it/s]
# (pid=69989) ./result/0001-0400/clip_123.jsonpickle
# 100%|██████████| 2749/2749 [00:00<00:00, 64177.92it/s]
# (pid=69990) video_to_frames done!!
# (pid=69990) json_to_info done!!
# (pid=69990) ./result/0001-0400/clip_69.jsonpickle
# (pid=69990) clip_id:  0001-0400/clip_7
# 100%|██████████| 1474/1474 [00:00<00:00, 63599.75it/s]
# (pid=70009) video_to_frames done!!
# (pid=70009) json_to_info done!!
#   0%|          | 0/1485 [00:00<?, ?it/s]
# (pid=70009) ./result/0001-0400/clip_76.jsonpickle
# 100%|██████████| 1485/1485 [00:00<00:00, 74619.23it/s]
# (pid=70009) clip_id:  0001-0400/clip_77
# (pid=69984) video_to_frames done!!
# (pid=69984) json_to_info done!!
#   0%|          | 0/2057 [00:00<?, ?it/s]
# (pid=69984) ./result/0001-0400/clip_134.jsonpickle
# 100%|██████████| 2057/2057 [00:00<00:00, 56859.08it/s]
# (pid=70012) video_to_frames done!!
# (pid=70012) json_to_info done!!
#   0%|          | 0/1501 [00:00<?, ?it/s]
# (pid=70012) ./result/0001-0400/clip_65.jsonpickle
# (pid=70012) clip_id:  0001-0400/clip_66
# 100%|██████████| 1501/1501 [00:00<00:00, 66025.36it/s]
# (pid=69998) video_to_frames done!!
# (pid=69998) json_to_info done!!
#   0%|          | 0/874 [00:00<?, ?it/s]
# (pid=69998) ./result/0001-0400/clip_90.jsonpickle
# 100%|██████████| 874/874 [00:00<00:00, 65800.68it/s]
# (pid=69998) clip_id:  0001-0400/clip_91
# (pid=69936) video_to_frames done!!
# (pid=69936) json_to_info done!!
# (pid=69936) ./result/0001-0400/clip_398.jsonpickle
# 100%|██████████| 1142/1142 [00:00<00:00, 60597.07it/s]
# (pid=69996) video_to_frames done!!
# (pid=69996) json_to_info done!!
#   0%|          | 0/1468 [00:00<?, ?it/s]
# (pid=69996) ./result/0001-0400/clip_43.jsonpickle
# (pid=69996) clip_id:  0001-0400/clip_44
# 100%|██████████| 1468/1468 [00:00<00:00, 66036.45it/s]
# (pid=69974) video_to_frames done!!
# (pid=69974) json_to_info done!!
# (pid=69974) ./result/0001-0400/clip_73.jsonpickle
# 100%|██████████| 870/870 [00:00<00:00, 65788.85it/s]
# (pid=70014) video_to_frames done!!
# (pid=70014) json_to_info done!!
# (pid=70014) ./result/0001-0400/clip_138.jsonpickle
# 100%|██████████| 1862/1862 [00:00<00:00, 84798.74it/s]
# (pid=69959) video_to_frames done!!
# (pid=69959) json_to_info done!!
# (pid=69959) ./result/0001-0400/clip_98.jsonpickle
# (pid=69959) clip_id:  0001-0400/clip_99
# 100%|██████████| 1360/1360 [00:00<00:00, 61400.76it/s]
# (pid=69940) video_to_frames done!!
# (pid=69940) json_to_info done!!
# (pid=69940) ./result/0001-0400/clip_8.jsonpickle
# (pid=69940) clip_id:  0001-0400/clip_80
# 100%|██████████| 532/532 [00:00<00:00, 87752.47it/s]
# (pid=69973) video_to_frames done!!
# (pid=69973) json_to_info done!!
#   0%|          | 0/1783 [00:00<?, ?it/s]
# (pid=69973) ./result/0001-0400/clip_50.jsonpickle
# (pid=69973) clip_id:  0001-0400/clip_51
# 100%|██████████| 1783/1783 [00:00<00:00, 84574.82it/s]
# (pid=69955) video_to_frames done!!
# (pid=69955) json_to_info done!!
# (pid=69955) ./result/0001-0400/clip_87.jsonpickle
# (pid=69955) clip_id:  0001-0400/clip_88
# 100%|██████████| 1124/1124 [00:00<00:00, 65734.29it/s]
# (pid=69980) video_to_frames done!!
# (pid=69980) json_to_info done!!
# (pid=69980) ./result/0001-0400/clip_54.jsonpickle
# 100%|██████████| 1307/1307 [00:00<00:00, 89536.40it/s]
# (pid=69980) clip_id:  0001-0400/clip_55
# (pid=69946) video_to_frames done!!
# (pid=69946) json_to_info done!!
# (pid=69946) ./result/0001-0400/clip_94.jsonpickle
# (pid=69946) clip_id:  0001-0400/clip_95
# 100%|██████████| 1354/1354 [00:00<00:00, 85088.89it/s]
# (pid=69971) video_to_frames done!!
# (pid=69971) json_to_info done!!
#   0%|          | 0/1588 [00:00<?, ?it/s]
# (pid=69971) ./result/0001-0400/clip_58.jsonpickle
# 100%|██████████| 1588/1588 [00:00<00:00, 26448.51it/s]
# (pid=69971) clip_id:  0001-0400/clip_59
# (pid=69932) video_to_frames done!!
# (pid=69932) json_to_info done!!
#   0%|          | 0/1813 [00:00<?, ?it/s]
# (pid=69932) ./result/0001-0400/clip_48.jsonpickle
# 100%|██████████| 1813/1813 [00:00<00:00, 66976.76it/s]
# (pid=70006) video_to_frames done!!
# (pid=70006) json_to_info done!!
# (pid=70006) ./result/0001-0400/clip_394.jsonpickle
# 100%|██████████| 1337/1337 [00:00<00:00, 64163.76it/s]
# (pid=69994) video_to_frames done!!
# (pid=69994) json_to_info done!!
# (pid=69994) ./result/0001-0400/clip_62.jsonpickle
# 100%|██████████| 1295/1295 [00:00<00:00, 93568.02it/s]
# (pid=69965) video_to_frames done!!
# (pid=69965) json_to_info done!!
# (pid=69965) ./result/0001-0400/clip_84.jsonpickle
# 100%|██████████| 1205/1205 [00:00<00:00, 86629.47it/s]
# (pid=70004) video_to_frames done!!
# (pid=70012) video_to_frames done!!
# (pid=70012) json_to_info done!!
#   0%|          | 0/1119 [00:00<?, ?it/s]
# (pid=70004) json_to_info done!!
# (pid=70004) ./result/0001-0400/clip_390.jsonpickle
# 100%|██████████| 1529/1529 [00:00<00:00, 86174.29it/s]
# (pid=70012) ./result/0001-0400/clip_66.jsonpickle
# 100%|██████████| 1119/1119 [00:00<00:00, 67058.53it/s]
# (pid=69998) video_to_frames done!!
# (pid=69998) json_to_info done!!
# (pid=69998) ./result/0001-0400/clip_91.jsonpickle
# 100%|██████████| 955/955 [00:00<00:00, 90693.30it/s]
# (pid=69990) video_to_frames done!!
# (pid=69990) json_to_info done!!
# (pid=69990) ./result/0001-0400/clip_7.jsonpickle
# 100%|██████████| 430/430 [00:00<00:00, 64530.06it/s]
# (pid=70009) video_to_frames done!!
# (pid=70009) json_to_info done!!
# (pid=70009) ./result/0001-0400/clip_77.jsonpickle
# 100%|██████████| 1251/1251 [00:00<00:00, 91229.67it/s]
# (pid=69973) video_to_frames done!!
# (pid=69973) json_to_info done!!
# (pid=69973) ./result/0001-0400/clip_51.jsonpickle
# 100%|██████████| 974/974 [00:00<00:00, 52515.07it/s]
# (pid=69940) video_to_frames done!!
# (pid=69940) json_to_info done!!
#   0%|          | 0/1270 [00:00<?, ?it/s]
# (pid=69940) ./result/0001-0400/clip_80.jsonpickle
# 100%|██████████| 1270/1270 [00:00<00:00, 67402.68it/s]
# (pid=69955) video_to_frames done!!
# (pid=69955) json_to_info done!!
# (pid=69955) ./result/0001-0400/clip_88.jsonpickle
# 100%|██████████| 983/983 [00:00<00:00, 66498.94it/s]
# (pid=69946) video_to_frames done!!
# (pid=69946) json_to_info done!!
# (pid=69946) ./result/0001-0400/clip_95.jsonpickle
# 100%|██████████| 860/860 [00:00<00:00, 93235.67it/s]
# (pid=69959) video_to_frames done!!
# (pid=69959) json_to_info done!!
# 100%|██████████| 1336/1336 [00:00<00:00, 94884.44it/s]
# (pid=69959) ./result/0001-0400/clip_99.jsonpickle
# (pid=69996) video_to_frames done!!
# (pid=69996) json_to_info done!!
# (pid=69996) ./result/0001-0400/clip_44.jsonpickle
# 100%|██████████| 1684/1684 [00:00<00:00, 64816.13it/s]
# (pid=69980) video_to_frames done!!
# (pid=69980) json_to_info done!!
# (pid=69980) ./result/0001-0400/clip_55.jsonpickle
# 100%|██████████| 1484/1484 [00:00<00:00, 66881.00it/s]
# (pid=69971) video_to_frames done!!
# (pid=69971) json_to_info done!!
# 100%|██████████| 1907/1907 [00:00<00:00, 66398.29it/s]
# (pid=69971) ./result/0001-0400/clip_59.jsonpickle
# CPU times: user 25.6 s, sys: 5.45 s, total: 31 s
# Wall time: 15min

# %% [markdown]
# ## 2. 파싱한 어노테이션을 읽어와서 224x224가 넘는 얼굴만 가져옴

# %% [markdown]
# ### 2.1 생성한 어노테이션 로딩

# %%
parsed_annotations = glob(os.path.join(OUTPUT_FOLDER,CLIP_FOLDER+'/*.jsonpickle'))

len(parsed_annotations), parsed_annotations[:2]
# Out:
# (400,
#  ['./result/0001-0400/clip_142.jsonpickle',
#   './result/0001-0400/clip_1.jsonpickle'])

# %%
@ray.remote
def load_filter(parsed_annotation_path:str):
        
    def _filter_image_size(a_frame_info:dict, clip_key:str, frame_key:str):
        img = plt.imread(a_frame_info['frame_image_path'])
        
        faces = detector(img)
        
        if len(faces) == 0:
            # 얼굴 못찾으면 삭제
            
            # print("faces : ", faces)
            #del #p_a_copy_224[clip_key][frame_key]
            del p_a_copy_48[clip_key][frame_key]
        elif len(faces) > 0:        
            minY = faces[0].top()
            maxY = faces[0].bottom()
            minX = faces[0].left()
            maxX = faces[0].right()
            face = img[minY:maxY,minX:maxX]   
            
            # print("maxY - minY ", maxY - minY, "maxX - minX ", maxX - minX)
            # tmp_test_size_list.append((maxY - minY, maxX - minX))
        
            if maxY - minY < 48 or maxX - minX < 48:                            
                del p_a_copy_48[clip_key][frame_key]
            else:
                p_a_copy_48[clip_key][frame_key]['ytl'] = minY
                p_a_copy_48[clip_key][frame_key]['ybr'] = maxY
                p_a_copy_48[clip_key][frame_key]['xtl'] = minX
                p_a_copy_48[clip_key][frame_key]['xbr'] = maxX
                
            #             if maxY - minY < 224 or maxX - minX < 224:
            #                 # 224 보다 사이즈가 작으면 삭제
            #                 del #p_a_copy_224[clip_key][frame_key]
            #             else:
            #                 # 224 보다 사이즈가 크면 얼굴 rect로 변경 (기존은 오브젝트 전체 rect)
            #                 #p_a_copy_224[clip_key][frame_key]['ytl'] = minY
            #                 #p_a_copy_224[clip_key][frame_key]['ybr'] = maxY
            #                 #p_a_copy_224[clip_key][frame_key]['xtl'] = minX
            #                 #p_a_copy_224[clip_key][frame_key]['xbr'] = maxX
                

    # tmp_test_size_list = []
    
    detector = dlib.get_frontal_face_detector()
    
    with open(parsed_annotation_path, 'rb') as f:
        p_a = pickle.load(f)
        
    #p_a_copy_224 = copy.deepcopy(p_a)
    p_a_copy_48 = copy.deepcopy(p_a)

    [ _filter_image_size(p_a[clip_key][frame_key], clip_key, frame_key ) for clip_key in p_a for frame_key in p_a[clip_key] ]
    
    return p_a_copy_48 #p_a_copy_224 #, 

def to_iterator(obj_ids):
    while obj_ids:
        done, obj_ids = ray.wait(obj_ids)
        yield ray.get(done[0])

# %% [markdown]
# ### 2.2 특정 사이즈의 얼굴 이미지가 포함된 데이터만 어노테이션 재생성

# %%
# 특정 사이즈의 얼굴 이미지가 포함된 데이터만 어노테이션 재생성
obj_ids = [load_filter.remote(p_a) for p_a in parsed_annotations]
for x in tqdm(to_iterator(obj_ids), total=len(obj_ids)):
    pass

# ray_result = ray.get([load_filter.remote(p_a) for p_a in parsed_annotations])

ray_result = ray.get(obj_ids)

total_result = {CLIP_FOLDER:ray_result}

with open(CLIP_FOLDER+'_annotation.json', 'w') as f:
    json.dump(total_result, f)

# %%
with open(CLIP_FOLDER+'_annotation.json', 'r') as f:
    j_load_tmp = json.load(f)

frame_list = []
[ frame_list.append(clips[clip_key][frame_key]) \
 for zip_file_key in j_load_tmp \
 for clips in j_load_tmp[zip_file_key] \
 for clip_key in clips \
 for frame_key in clips[clip_key] ]
""
# Out:
# ''

# %%
len(frame_list), frame_list[300000]
# Out:
# (470438,
#  {'person_id': '20',
#   'age': '40s',
#   'gender': 'female',
#   'emotion': {'image': {'emotion': 'surprise', 'valence': 4, 'arousal': 2}},
#   'xtl': 880,
#   'xbr': 966,
#   'ytl': 285,
#   'ybr': 371,
#   'frame_image_path': './result/0001-0400/clip_372/688.jpg'})

# %%
@ray.remote
def parsing_json_to_csv_with_img(i_list:list, idx:int):
    #     print(i_list)
    result_list = []
    for i in i_list:    
        img = Image.open(i['frame_image_path']).convert('L')
        img = img.crop((i['xtl'],i['ytl'], i['xbr'], i['ybr']))

        w = img.size[0]
        h = img.size[1]

        if h > 48 or w > 48:
            resized_face_gray_img = np.array(img.resize((48, 48)), 'uint8')
            #             resized_face_gray_img = resized_face_gray_img.reshape(48*48)
            result_list.append((i['emotion']['image']['emotion'], resized_face_gray_img))

    with open(os.path.join(OUTPUT_FOLDER,CLIP_FOLDER,CLIP_FOLDER+'_'+str(idx)+'.csv'), 'w') as f:
        csv_writer = csv.writer(f)
        csv_writer.writerow(['emotion','face_img'])
        #     csv_writer.writerows(result_total_anno_list)
        #     [csv_writer.writerow(row) for row in result_total_anno_list]    
        [csv_writer.writerow((anno[0], " ".join(list(anno[1].reshape(48*48).astype(np.str))))) for anno in result_list]                

def parsing_json_to_csv_with_img_single(i_list:list):
    result_list = []
    for i in i_list:    
        img = Image.open(i['frame_image_path']).convert('L')
        img = img.crop((i['xtl'],i['ytl'], i['xbr'], i['ybr']))

        w = img.size[0]
        h = img.size[1]
        
        if h > 48 or w > 48:        
            resized_face_gray_img = np.array(img.resize((48, 48)), 'uint8')
            result_list.append((i['emotion']['image']['emotion'], resized_face_gray_img))
            
    with open(os.path.join(OUTPUT_FOLDER,CLIP_FOLDER,CLIP_FOLDER+'_'+str(idx)+'.csv'), 'w') as f:
        csv_writer = csv.writer(f)
        csv_writer.writerow(['emotion','face_img'])
        #     csv_writer.writerows(result_total_anno_list)
        #     [csv_writer.writerow(row) for row in result_total_anno_list]    
        [csv_writer.writerow((anno[0], " ".join(list(anno[1].reshape(48*48).astype(np.str))))) for anno in result_list]

# %%
num_partition = 20
seq_rest_partition = 21
num_frame_list = len(frame_list)
num_sub_frame_list = num_frame_list // num_partition
num_rest_sub_frame_list = num_frame_list - (num_sub_frame_list * num_partition)

# 파티션 단위로 처리
result_obj_ids = [parsing_json_to_csv_with_img.remote(frame_list[(0+i)*num_sub_frame_list:(1+i)*num_sub_frame_list], i) for i in range(num_partition) ]
for x in tqdm(to_iterator(result_obj_ids), total=len(result_obj_ids)):
    pass

# 나머지 소수 남은 데이터 처리
parsing_json_to_csv_with_img_single(frame_list[num_sub_frame_list * 100:(num_sub_frame_list * 100)+num_rest_sub_frame_list], seq_rest_partition)

# %%
len(frame_list)
# Out:
# 470438

# %%
for i in range(20):
    print((0+i)*num_sub_frame_list,(1+i)*num_sub_frame_list)
# Out:
# 0 23521
# 23521 47042
# 47042 70563
# 70563 94084
# 94084 117605
# 117605 141126
# 141126 164647
# 164647 188168
# 188168 211689
# 211689 235210
# 235210 258731
# 258731 282252
# 282252 305773
# 305773 329294
# 329294 352815
# 352815 376336
# 376336 399857
# 399857 423378
# 423378 446899
# 446899 470420

# %%
# detector = dlib.get_frontal_face_detector()

# for clip_idx in face_info_with_imgs:

#     for frame_idx in face_info_with_imgs[clip_idx]:
        
#         # load img
#         img = plt.imread(face_info_with_imgs[clip_idx][frame_idx]['frame_image_path'])
#         print('----------- img path: ', face_info_with_imgs[clip_idx][frame_idx]['frame_image_path'])
#         print(face_info_with_imgs[clip_idx][frame_idx]['emotion'])
        
#         # slice object
#         xtl = int(face_info_with_imgs[clip_idx][frame_idx]['xtl'])
#         xbr = int(face_info_with_imgs[clip_idx][frame_idx]['xbr'])
#         ytl = int(face_info_with_imgs[clip_idx][frame_idx]['ytl'])
#         ybr = int(face_info_with_imgs[clip_idx][frame_idx]['ybr'])

#         obj = img[ytl:ybr+1, xtl:xbr+1]
#         faces = detector(obj)
        
#         minY = faces[0].top()
#         maxY = faces[0].bottom()
#         minX = faces[0].left()
#         maxX = faces[0].right()
#         face = obj[minY:maxY,minX:maxX]
#         plt.imshow(face)
        
#         break
#     break
